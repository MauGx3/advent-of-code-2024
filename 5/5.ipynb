# %% [markdown]
# # Day 5: Print Queue
#
# [https://adventofcode.com/2024/day/5](https://adventofcode.com/2024/day/5)
#
# ## Description
#
# ### Part One
#
# Satisfied with their search on Ceres, the squadron of scholars suggests subsequently scanning the `<span title="Specifically, the surely-stationary stationery stacks.">`stationery stacks of sub-basement 17.
#
# The North Pole printing department is busier than ever this close to Christmas, and while The Historians continue their search of this historically significant facility, an Elf operating a [very familiar printer](https://adventofcode.com/2017/day/1) beckons you over.
#
# The Elf must recognize you, because they waste no time explaining that the new _sleigh launch safety manual_ updates won't print correctly. Failure to update the safety manuals would be dire indeed, so you offer your services.
#
# Safety protocols clearly indicate that new pages for the safety manuals must be printed in a _very specific order_. The notation `X|Y` means that if both page number `X` and page number `Y` are to be produced as part of an update, page number `X` _must_ be printed at some point before page number `Y`.
#
# The Elf has for you both the _page ordering rules_ and the _pages to produce in each update_ (your puzzle input), but can't figure out whether each update has the pages in the right order.
#
# For example:
#
#     47|53
#     97|13
#     97|61
#     97|47
#     75|29
#     61|13
#     75|53
#     29|13
#     97|29
#     53|29
#     61|53
#     97|53
#     61|29
#     47|13
#     75|47
#     97|75
#     47|61
#     75|61
#     47|29
#     75|13
#     53|13
#
#     75,47,61,53,29
#     97,61,53,29,13
#     75,29,13
#     75,97,47,61,53
#     61,13,29
#     97,13,75,29,47
#
# The first section specifies the _page ordering rules_, one per line. The first rule, `47|53`, means that if an update includes both page number 47 and page number 53, then page number 47 _must_ be printed at some point before page number 53. (47 doesn't necessarily need to be _immediately_ before 53; other pages are allowed to be between them.)
#
# The second section specifies the page numbers of each _update_. Because most safety manuals are different, the pages needed in the updates are different too. The first update, `75,47,61,53,29`, means that the update consists of page numbers 75, 47, 61, 53, and 29.
#
# To get the printers going as soon as possible, start by identifying _which updates are already in the right order_.
#
# In the above example, the first update (`75,47,61,53,29`) is in the right order:
#
# * `75` is correctly first because there are rules that put each other page after it: `75|47`, `75|61`, `75|53`, and `75|29`.
# * `47` is correctly second because 75 must be before it (`75|47`) and every other page must be after it according to `47|61`, `47|53`, and `47|29`.
# * `61` is correctly in the middle because 75 and 47 are before it (`75|61` and `47|61`) and 53 and 29 are after it (`61|53` and `61|29`).
# * `53` is correctly fourth because it is before page number 29 (`53|29`).
# * `29` is the only page left and so is correctly last.
#
# Because the first update does not include some page numbers, the ordering rules involving those missing page numbers are ignored.
#
# The second and third updates are also in the correct order according to the rules. Like the first update, they also do not include every page number, and so only some of the ordering rules apply - within each update, the ordering rules that involve missing page numbers are not used.
#
# The fourth update, `75,97,47,61,53`, is _not_ in the correct order: it would print 75 before 97, which violates the rule `97|75`.
#
# The fifth update, `61,13,29`, is also _not_ in the correct order, since it breaks the rule `29|13`.
#
# The last update, `97,13,75,29,47`, is _not_ in the correct order due to breaking several rules.
#
# For some reason, the Elves also need to know the _middle page number_ of each update being printed. Because you are currently only printing the correctly-ordered updates, you will need to find the middle page number of each correctly-ordered update. In the above example, the correctly-ordered updates are:
#
#     75,47,61,53,29
#     97,61,53,29,13
#     75,29,13
#
# These have middle page numbers of `61`, `53`, and `29` respectively. Adding these page numbers together gives _`143`_.
#
# Of course, you'll need to be careful: the actual list of _page ordering rules_ is bigger and more complicated than the above example.
#
# Determine which updates are already in the correct order. _What do you get if you add up the middle page number from those correctly-ordered updates?_

# %% [markdown]
# #### Code

# %%
with open("example_pageordering.txt") as f:
    page_ordering = f.read().splitlines()

# %%
page_ordering
# Out:
# ['47|53',
#  '97|13',
#  '97|61',
#  '97|47',
#  '75|29',
#  '61|13',
#  '75|53',
#  '29|13',
#  '97|29',
#  '53|29',
#  '61|53',
#  '97|53',
#  '61|29',
#  '47|13',
#  '75|47',
#  '97|75',
#  '47|61',
#  '75|61',
#  '47|29',
#  '75|13',
#  '53|13']

# %%
with open('example_updates.txt') as f:
    updates = f.read().splitlines()
    updates = [page.split(',') for page in updates]

# %%
updates = [[int(num) for num in update] for update in updates]

# %%
updates
# Out:
# [[75, 47, 61, 53, 29],
#  [97, 61, 53, 29, 13],
#  [75, 29, 13],
#  [75, 97, 47, 61, 53],
#  [61, 13, 29],
#  [97, 13, 75, 29, 47]]

# %% [markdown]
# Could of course use regex here, would be much faster and easier

# %%
def check_order(page_ordering):
    # list comprehension (by Claude)
    x_col, y_col = zip(*(page.split("|") for page in page_ordering))
    # original code
    x_col = []
    y_col = []

    for page in page_ordering:
        x, y = page.split("|")
        x_col.append(int(x))
        y_col.append(int(y))

    order = list(zip(x_col, y_col))

    x_max, y_max = max(x_col), max(y_col)
    x_ordered = ['' for i in range(x_max)]
    # y_ordered = ['' for i in range(y_max)]

    for x in x_col:
        x_ordered[x-1] = x
    # for y in y_col:
    #     y_ordered[y-1] = y

    x_ordered = [x for x in x_ordered if x != '']
    x_ordered.sort()
    # y_ordered = [y for y in y_ordered if y != '']

    return x_col, y_col, order, x_ordered

# %%
x_col, y_col, order, x_ordered = check_order(page_ordering)
order
# Out:
# [(47, 53),
#  (97, 13),
#  (97, 61),
#  (97, 47),
#  (75, 29),
#  (61, 13),
#  (75, 53),
#  (29, 13),
#  (97, 29),
#  (53, 29),
#  (61, 53),
#  (97, 53),
#  (61, 29),
#  (47, 13),
#  (75, 47),
#  (97, 75),
#  (47, 61),
#  (75, 61),
#  (47, 29),
#  (75, 13),
#  (53, 13)]

# %%
for tup in order:
    if tup[0] == 47:
        print(tup)
# Out:
# (47, 53)
# (47, 13)
# (47, 61)
# (47, 29)

# %%
def find_matches(order, x_ordered=None, y_ordered=None, target=None):
    matches = []
    if x_ordered:
        for page in x_ordered:
            first_value = page  # Get the first value (x)

            for potential_match in order:
                if first_value == potential_match[0]:  # If x matches the first value
                    matches.append((first_value, potential_match))

    if y_ordered:
        for page in y_ordered:
            first_value = page

            for potential_match in order:
                if first_value == potential_match[0]:  # If x matches the first value
                    matches.append((first_value, potential_match))

    if target:
        first_value = target
        for potential_match in order:
            if first_value == potential_match[0]:  # If x matches the first value
                matches.append((first_value, potential_match))

    return matches


# Example usage:
results = find_matches(order, target=75)
for match in results:
    print(f"Value {match[0]} matches tuple {match[1]}")
# Out:
# Value 75 matches tuple (75, 29)
# Value 75 matches tuple (75, 53)
# Value 75 matches tuple (75, 47)
# Value 75 matches tuple (75, 61)
# Value 75 matches tuple (75, 13)

# %%
def find_matches_comprehension(order):
    return [(t1[0], t2) for t1 in order for t2 in order if t1[0] == t2[1]]

# %%
for line in updates:
    print(f"Checking update: {line}")
    for page in line:
        results = find_matches(order, target=int(page))
        rules = []
        for match in results:
            rules.append(match[1][1])
            print(f"Value {match[0]} matches tuple {match[1]}")
        print(f"Rules: {rules}")
        if any(rule > page for rule in rules):
            # todo remover o anterior para checagem correta?
            print(f"Page {page} is out of order\n")
        else:
            print(f"Page {page} is in order\n")
    break
# Out:
# Checking update: [75, 47, 61, 53, 29]
# Value 75 matches tuple (75, 29)
# Value 75 matches tuple (75, 53)
# Value 75 matches tuple (75, 47)
# Value 75 matches tuple (75, 61)
# Value 75 matches tuple (75, 13)
# Rules: [29, 53, 47, 61, 13]
# Page 75 is in order
#
# Value 47 matches tuple (47, 53)
# Value 47 matches tuple (47, 13)
# Value 47 matches tuple (47, 61)
# Value 47 matches tuple (47, 29)
# Rules: [53, 13, 61, 29]
# Page 47 is out of order
#
# Value 61 matches tuple (61, 13)
# Value 61 matches tuple (61, 53)
# Value 61 matches tuple (61, 29)
# Rules: [13, 53, 29]
# Page 61 is in order
#
# Value 53 matches tuple (53, 29)
# Value 53 matches tuple (53, 13)
# Rules: [29, 13]
# Page 53 is in order
#
# Value 29 matches tuple (29, 13)
# Rules: [13]
# Page 29 is in order

# %% [markdown]
# #### Claude help

# %%
def check_update_order(update, order):
    # Convert order rules to a more usable format
    rules = {}
    for x, y in order:
        if x not in rules:
            rules[x] = set()
        rules[x].add(y)

    # For each position in the update
    for i, current_page in enumerate(update):
        if current_page in rules:
            # Get all pages that should come after current_page
            must_come_after = rules[current_page]
            # Check remaining pages in the update
            remaining_pages = set(update[i+1:])
            # If any page that must come after is not in the remaining pages
            # and is present in the update, the order is wrong
            for page in must_come_after:
                if page in update[:i]:
                    return False
    return True

for line in updates:
    is_ordered = check_update_order(line, order)
    print(f"Update {line} is {'in correct order' if is_ordered else 'out of order'}")
# Out:
# Update [75, 47, 61, 53, 29] is in correct order
# Update [97, 61, 53, 29, 13] is in correct order
# Update [75, 29, 13] is in correct order
# Update [75, 97, 47, 61, 53] is out of order
# Update [61, 13, 29] is out of order
# Update [97, 13, 75, 29, 47] is out of order

# %% [markdown]
# Certainly! Let's break down the `check_update_order` function:
#
# 1. The function takes two parameters:
#    - `update`: A list of page numbers in the order they appear in an update.
#    - `order`: A list of tuples representing the ordering rules.
#
# 2. It starts by creating a dictionary `rules` to store the ordering rules in a more efficient format:
#    - Keys are page numbers (x)
#    - Values are sets of page numbers (y) that should come after x
#
# 3. The main loop iterates through each page number in the update:
#    ```python
#    for i, current_page in enumerate(update):
#    ```
#
# 4. For each page, it checks if there are any rules associated with it:
#    ```python
#    if current_page in rules:
#    ```
#
# 5. If there are rules, it gets the set of pages that should come after the current page:
#    ```python
#    must_come_after = rules[current_page]
#    ```
#
# 6. It then checks if any of the pages that should come after the current page appear before it in the update:
#    ```python
#    for page in must_come_after:
#        if page in update[:i]:
#            return False
#    ```
#    If any such page is found, it means the order is incorrect, and the function returns `False`.
#
# 7. If the loop completes without finding any violations, the function returns `True`, indicating that the update is in the correct order.
#
# This function efficiently checks if an update follows all the ordering rules by:
# - Converting the rules to a more easily searchable format
# - Checking each page against only the relevant rules
# - Returning early if any violation is found
#
# The time complexity of this function is O(n*m), where n is the length of the update and m is the maximum number of rules for any single page.

# %%
for line in updates:
    print(f"Checking update: {line}")
    for page in line:
        results = find_matches(order, target=int(page))
        rules = []
        for match in results:
            rules.append((match[1]))
            print(f"Value {match[0]} matches tuple {match[1]}")
        print(f"Rules: {rules}")
    #     if any(rule > page for rule in rules):
    #         # todo remover o anterior para checagem correta?
    #         print(f"Page {page} is out of order\n")
    #     else:
    #         print(f"Page {page} is in order\n")
        for i, current_page in enumerate(line):
            print(current_page)
            print(rules)
            if current_page in rules:
                must_come_after = rules[current_page]
                print(must_come_after)
    break
# Out:
# Checking update: [75, 47, 61, 53, 29]
# Value 75 matches tuple (75, 29)
# Value 75 matches tuple (75, 53)
# Value 75 matches tuple (75, 47)
# Value 75 matches tuple (75, 61)
# Value 75 matches tuple (75, 13)
# Rules: [(75, 29), (75, 53), (75, 47), (75, 61), (75, 13)]
# 75
# [(75, 29), (75, 53), (75, 47), (75, 61), (75, 13)]
# 47
# [(75, 29), (75, 53), (75, 47), (75, 61), (75, 13)]
# 61
# [(75, 29), (75, 53), (75, 47), (75, 61), (75, 13)]
# 53
# [(75, 29), (75, 53), (75, 47), (75, 61), (75, 13)]
# 29
# [(75, 29), (75, 53), (75, 47), (75, 61), (75, 13)]
# Value 47 matches tuple (47, 53)
# Value 47 matches tuple (47, 13)
# Value 47 matches tuple (47, 61)
# Value 47 matches tuple (47, 29)
# Rules: [(47, 53), (47, 13), (47, 61), (47, 29)]
# 75
# [(47, 53), (47, 13), (47, 61), (47, 29)]
# 47
# [(47, 53), (47, 13), (47, 61), (47, 29)]
# 61
# [(47, 53), (47, 13), (47, 61), (47, 29)]
# 53
# [(47, 53), (47, 13), (47, 61), (47, 29)]
# 29
# [(47, 53), (47, 13), (47, 61), (47, 29)]
# Value 61 matches tuple (61, 13)
# Value 61 matches tuple (61, 53)
# Value 61 matches tuple (61, 29)
# Rules: [(61, 13), (61, 53), (61, 29)]
# 75
# [(61, 13), (61, 53), (61, 29)]
# 47
# [(61, 13), (61, 53), (61, 29)]
# 61
# [(61, 13), (61, 53), (61, 29)]
# 53
# [(61, 13), (61, 53), (61, 29)]
# 29
# [(61, 13), (61, 53), (61, 29)]
# Value 53 matches tuple (53, 29)
# Value 53 matches tuple (53, 13)
# Rules: [(53, 29), (53, 13)]
# 75
# [(53, 29), (53, 13)]
# 47
# [(53, 29), (53, 13)]
# 61
# [(53, 29), (53, 13)]
# 53
# [(53, 29), (53, 13)]
# 29
# [(53, 29), (53, 13)]
# Value 29 matches tuple (29, 13)
# Rules: [(29, 13)]
# 75
# [(29, 13)]
# 47
# [(29, 13)]
# 61
# [(29, 13)]
# 53
# [(29, 13)]
# 29
# [(29, 13)]

# %% [markdown]
# #### Excecuting the puzzle

# %%
with open("input.txt") as f:
    page_ordering = f.read()

page_ordering = page_ordering.split("\n\n")

rules = page_ordering[0].split()

updates = page_ordering[1].split()
updates = [page.split(",") for page in updates]
updates = [[int(num) for num in update] for update in updates]

# %%
x_col, y_col, order, x_ordered = check_order(rules)

# %%
in_order = []
for line in updates:
    is_ordered = check_update_order(line, order)
    if is_ordered:
        in_order.append(line)
    print(f"Update {line} is {'in correct order' if is_ordered else 'out of order'}")
# Out:
# Update [38, 68, 88, 11, 13, 64, 29, 37, 92, 72, 26, 83, 89] is in correct order
# Update [92, 12, 72, 26, 51, 83, 79, 76, 24, 17, 49, 42, 87, 25, 63, 18, 84] is in correct order
# Update [37, 26, 79, 73, 87] is in correct order
# Update [15, 47, 78, 68, 53] is out of order
# Update [93, 17, 49, 63, 18, 23, 96, 47, 36, 34, 44] is in correct order
# Update [11, 36, 88, 13, 59, 38, 46, 34, 71, 68, 12, 31, 92, 54, 47, 44, 29, 37, 64, 78, 74] is out of order
# Update [26, 72, 42, 84, 87, 65, 24, 12, 79] is out of order
# Update [41, 13, 53, 92, 51, 83, 76, 93, 49] is in correct order
# Update [26, 78, 74, 51, 56, 37, 41, 88, 59, 31, 68, 13, 34, 92, 44, 64, 71, 15, 72] is out of order
# Update [47, 59, 15, 71, 41, 53, 12] is in correct order
# Update [72, 82, 89, 83, 92, 37, 42, 53, 87, 73, 76, 26, 78, 49, 79] is out of order
# Update [13, 51, 83, 29, 37, 92, 78, 68, 41, 44, 88, 38, 26, 53, 11, 64, 34, 12, 74] is out of order
# Update [93, 73, 17, 49, 42, 35, 87, 25, 98, 63, 18, 84, 65, 23, 96, 47, 54, 36, 46, 59, 34, 38, 74] is in correct order
# Update [23, 35, 63, 42, 46, 25, 93, 79, 98, 87, 36, 54, 18, 76, 73, 49, 65] is out of order
# Update [93, 73, 17, 49, 42, 35, 98, 84, 23, 96, 47, 54, 36, 46, 59, 34, 38, 44, 74] is in correct order
# Update [51, 64, 72, 37, 12, 42, 35, 49, 89, 82, 73, 26, 93, 56, 13, 29, 79, 78, 92, 24, 83] is out of order
# Update [24, 73, 17, 49, 87, 63, 96, 47, 36, 59, 34, 38, 44] is in correct order
# Update [44, 59, 71, 78, 37, 92, 12, 31, 88] is out of order
# Update [93, 11, 51, 82, 26, 53, 24, 42, 76] is out of order
# Update [72, 56, 51, 83, 89, 82, 79, 76, 24, 73, 42, 87, 98, 63, 84, 65, 23] is in correct order
# Update [15, 88, 41, 13, 29, 53, 92, 56, 51, 89, 76] is in correct order
# Update [15, 46, 38, 36, 17, 23, 63, 84, 35, 73, 59, 74, 98, 65, 34, 96, 25] is out of order
# Update [23, 54, 36, 46, 59, 34, 44, 74, 15, 31, 88, 71, 41, 11, 13, 29, 37] is in correct order
# Update [68, 71, 41, 11, 13, 64, 29, 53, 78, 37, 92, 12, 72, 56, 26, 51, 83, 89, 82, 
# Update [13, 78, 49, 24, 92, 53, 72, 11, 26, 51, 17, 37, 56, 73, 12, 42, 89] is out of order
# Update [83, 89, 79, 76, 24, 93, 73, 17, 49, 35, 25, 98, 63, 84, 65, 47, 36] is in correct order
# Update [88, 41, 13, 64, 53, 78, 37, 12, 26, 83, 79, 76, 24, 93, 73] is in correct order
# Update [84, 87, 82, 42, 63, 49, 96, 73, 56] is out of order
# Update [71, 13, 29, 44, 53, 59, 54, 74, 47, 64, 37, 38, 68, 96, 15, 23, 34] is out of order
# Update [87, 44, 18, 54, 31, 71, 74, 84, 47, 65, 15, 23, 98, 35, 59] is out of order
# Update [79, 51, 68, 12, 53, 29, 72, 26, 83, 71, 88, 11, 31, 13, 74, 82, 15, 37, 64, 92, 56] is out of order
# Update [89, 87, 64, 26, 79, 56, 83] is out of order

# %%
def find_middle(lst):
    if not lst:  # Check if the list is empty
        return False

    length = len(lst)  # Get the length of the list

    if length % 2 != 0:  # Check if the length is odd
        middle_index = length // 2
        return lst[middle_index]

    # If the length is even
    first_middle_index = length // 2 - 1
    second_middle_index = length // 2
    return (lst[first_middle_index], lst[second_middle_index])

# %%
page_number_sum = 0
for line in in_order:
    middle = find_middle(line)
    print(f"Middle of {line} is {middle}")
    page_number_sum += middle
# Out:
# Middle of [38, 68, 88, 11, 13, 64, 29, 37, 92, 72, 26, 83, 89] is 29
# Middle of [92, 12, 72, 26, 51, 83, 79, 76, 24, 17, 49, 42, 87, 25, 63, 18, 84] is 24
# Middle of [37, 26, 79, 73, 87] is 79
# Middle of [93, 17, 49, 63, 18, 23, 96, 47, 36, 34, 44] is 23
# Middle of [41, 13, 53, 92, 51, 83, 76, 93, 49] is 51
# Middle of [47, 59, 15, 71, 41, 53, 12] is 71
# Middle of [93, 73, 17, 49, 42, 35, 87, 25, 98, 63, 18, 84, 65, 23, 96, 47, 54, 36, 46, 59, 34, 38, 74] is 84
# Middle of [93, 73, 17, 49, 42, 35, 98, 84, 23, 96, 47, 54, 36, 46, 59, 34, 38, 44, 74] is 96
# Middle of [24, 73, 17, 49, 87, 63, 96, 47, 36, 59, 34, 38, 44] is 96
# Middle of [72, 56, 51, 83, 89, 82, 79, 76, 24, 73, 42, 87, 98, 63, 84, 65, 23] is 24
# Middle of [15, 88, 41, 13, 29, 53, 92, 56, 51, 89, 76] is 53
# Middle of [23, 54, 36, 46, 59, 34, 44, 74, 15, 31, 88, 71, 41, 11, 13, 29, 37] is 15
# Middle of [68, 71, 41, 11, 13, 64, 29, 53, 78, 37, 92, 12, 72, 56, 26, 51, 83, 89, 82, 79, 24] is 92
# Middle of [93, 73, 17, 49, 87, 98, 18, 84, 65, 23, 96, 47, 54, 36, 59, 34, 38, 44, 74] is 23
# Middle of [87, 98, 84, 65, 96, 47, 46, 59, 34, 74, 15, 31, 88, 71, 41] is 59
# Middle of [72, 56, 51, 83, 89, 76, 24, 93, 17, 49, 35, 98, 63, 18, 84] is 93
# Middle of [44, 15, 68, 31, 88, 71, 41, 13, 29, 53, 92, 12, 56, 26, 51, 83, 89] is 29
# Middle of [53, 78, 37, 92, 12, 72, 56, 26, 51, 83, 89, 82, 
 64, 29, 53, 78, 37, 92, 12, 72, 56, 26, 51, 83] is 64
# Middle of [88, 71, 64, 29, 37, 92, 72, 89, 73] is 37
# Middle of [44, 31, 88, 71, 41, 13, 64, 78, 37, 92, 12, 72, 89] is 64
# Middle of [12, 72, 56, 26, 51, 83, 89, 82, 79, 24, 93, 73, 17, 49, 87, 25, 98, 63, 84] is 24
# Middle of [31, 88, 71, 41, 11, 13, 64, 29, 53, 78, 37, 92, 12, 72, 56, 26, 51, 83, 89, 79, 76, 24, 93] is 92
# Middle of [98, 65, 23, 96, 47, 54, 36, 46, 59, 34, 38, 74, 31, 41, 13] is 46
# Middle of [89, 98, 18, 84, 96, 54, 46] is 84
# Middle of [53, 78, 72, 56, 51, 76, 49, 25, 98] is 51
# Middle of [23, 96, 74, 71, 13] is 74
# Middle of [13, 53, 92, 12, 51, 83, 79, 76, 24, 17, 35] is 83
# Middle of [17, 42, 35, 25, 84, 65, 23, 96, 54, 46, 44] is 65
# Middle of [78, 37, 92, 12, 26, 51, 79, 24, 49, 42, 35, 87, 25, 98, 63] is 24
# Middle of [65, 23, 96, 47, 54, 46, 59, 34, 44, 74, 15, 31, 88, 41, 64, 29, 78] is 44
# Middle of [31, 41, 11, 64, 29, 92, 93] is 64
# Middle of [18, 65, 23, 96, 47, 54, 36, 59, 44, 15, 31, 71, 41, 11, 13, 64, 29] is 44
# Middle of [83, 89, 79, 76, 24, 93, 73, 17, 49, 35, 25, 98, 63, 84, 65, 47, 36] is 49
# Middle of [88, 41, 13, 64, 53, 78, 37, 12, 26, 83, 79, 76, 24, 93, 73] is 12

# %%
page_number_sum
# Out:
# 5374

# %% [markdown]
# ### Part Two
#
# While the Elves get to work printing the correctly-ordered updates, you have a little time to fix the rest of them.
#
# For each of the _incorrectly-ordered updates_, use the page ordering rules to put the page numbers in the right order. For the above example, here are the three incorrectly-ordered updates and their correct orderings:
#
# * `75,97,47,61,53` becomes `97,75,47,61,53`.
# * `61,13,29` becomes `61,29,13`.
# * `97,13,75,29,47` becomes `97,75,47,29,13`.
#
# After taking _only the incorrectly-ordered updates_ and ordering them correctly, their middle page numbers are `47`, `29`, and `47`. Adding these together produces _`123`_.
#
# Find the updates which are not in the correct order. _What do you get if you add up the middle page numbers after correctly ordering just those updates?_

# %% [markdown]
# #### Example

# %%
with open("example_pageordering.txt") as f:
    page_ordering = f.read().split('\n')

with open("example_updates.txt") as f:
    updates = f.read().splitlines()
    updates = [page.split(",") for page in updates]
    updates = [[int(num) for num in update] for update in updates]

x_col, y_col, order, x_ordered = check_order(page_ordering)

# %%
ooo = []
for line in updates:
    is_ordered = check_update_order(line, order)
    if not is_ordered:
        ooo.append(line)

# %%
def swap_values(lst, val1, val2):
    """
    Swap the positions of two values in a list.

    Args:
        lst (list): The input list
        val1: First value to swap
        val2: Second value to swap

    Returns:
        list: New list with swapped values
    """
    # Create a copy of the list
    new_list = lst.copy()

    # Find indices of both values
    try:
        index1 = new_list.index(val1)
        index2 = new_list.index(val2)

        # Swap the values
        new_list[index1], new_list[index2] = new_list[index2], new_list[index1]

        return new_list
    except ValueError:
        print(f"One or both values ({val1}, {val2}) not found in list")
        return new_list

# %%
def fix_update_order(update, order):
    print(f"Checking update: {update}\n")
    rules = {}
    for x, y in order:
        if x not in rules:
            rules[x] = set()
        rules[x].add(y)
    # print(f'Rules: {rules}')

    fixed_update = None

    for i, current_page in enumerate(update):
        if fixed_update:
            update = fixed_update
        print(f'Current page: {current_page}')
        if current_page in rules:
            print(f'Pages that must come after {current_page}: {rules[current_page]}')
            must_come_after = rules[current_page]
            # print(f'Pages that should come after current_page: {must_come_after}')
            if not fixed_update:
                remaining_pages = set(update[i + 1 :])
            else:
                remaining_pages = set(fixed_update[i + 1 :])
            print(f'Remaining pages: {remaining_pages}')
            for page in must_come_after:
                if page in update[:i]:
                    # print(f'{update}')
                    print(f"Page {page} is out of order")
                    if page in rules:
                        print(f'Pages that must come after out of order page {page}: {rules[page]}')
                        # todo swap with a page that is in must_come_after
                        for value in rules[page]:
                            if value in update:
                                fixed_update = swap_values(update, page, current_page)
                                # todo need to add check if is legal update
                                print(f"Swapped {page} with {value}: new update is: {fixed_update}")
                                break
                        if fixed_update:
                            return fixed_update
                        else:
                            if value in update:
                                fixed_update = swap_values(update, page, current_page)
                                # todo need to add check if is legal update
                                print(f"Swapped {page} with {value}: new update is: {fixed_update}")
                                break
                    else:
                        fixed_update = swap_values(update, page, update[-1])
                        # return fixed_update
        # print("\n")
        else:
            print(f'Current page {current_page} is not in rules\n')
            fixed_update = swap_values(update, current_page, update[-1])
            # return fixed_update
        print(f'Fixed update for now: {fixed_update}\n')
    # print(f"Update is in order: {update}\n")
    # return update
    if fixed_update:
        return fixed_update
    else:
        return update

# %%
for line in ooo:
    print(line)
    fix_update_order(line, order)
# Out:
# [75, 97, 47, 61, 53]
# Checking update: [75, 97, 47, 61, 53]
#
# Current page: 75
# Pages that must come after 75: {13, 47, 29, 53, 61}
# Remaining pages: {97, 53, 61, 47}
# Fixed update for now: None
#
# Current page: 97
# Pages that must come after 97: {75, 13, 47, 61, 53, 29}
# Remaining pages: {53, 61, 47}
# Page 75 is out of order
# Pages that must come after out of order page 75: {13, 47, 29, 53, 61}
# Swapped 75 with 47: new update is: [97, 75, 47, 61, 53]
# [61, 13, 29]
# Checking update: [61, 13, 29]
#
# Current page: 61
# Pages that must come after 61: {29, 53, 13}
# Remaining pages: {29, 13}
# Fixed update for now: None
#
# Current page: 13
# Current page 13 is not in rules
#
# Fixed update for now: [61, 29, 13]
#
# Current page: 29
# Pages that must come after 29: {13}
# Remaining pages: set()
# Fixed update for now: [61, 29, 13]
#
# [97, 13, 75, 29, 47]
# Checking update: [97, 13, 75, 29, 47]
#
# Current page: 97
# Pages that must come after 97: {75, 13, 47, 61, 53, 29}
# Remaining pages: {29, 75, 13, 47}
# Fixed update for now: None
#
# Current page: 13
# Current page 13 is not in rules
#
# Fixed update for now: [97, 47, 75, 29, 13]
#
# Current page: 75
# Pages that must come after 75: {13, 47, 29, 53, 61}
# Remaining pages: {13, 29}
# Page 47 is out of order
# Pages that must come after out of order page 47: {29, 13, 61, 53}
# Swapped 47 with 29: new update is: [97, 75, 47, 29, 13]

# %%
fixed_updates = []
for line in ooo:
    print(line)
    update_check = fix_update_order(line, order)
    if fix_update_order(line, order):
        fixed_updates.append(update_check)

fixed_page_number_sum = 0
for line in fixed_updates:
    middle = find_middle(line)
    # print(f"Middle of {line} is {middle}")
    fixed_page_number_sum += middle

fixed_page_number_sum
# Out:
# [75, 97, 47, 61, 53]
# Checking update: [75, 97, 47, 61, 53]
#
# Current page: 75
# Pages that must come after 75: {13, 47, 29, 53, 61}
# Remaining pages: {97, 53, 61, 47}
# Fixed update for now: None
#
# Current page: 97
# Pages that must come after 97: {75, 13, 47, 61, 53, 29}
# Remaining pages: {53, 61, 47}
# Page 75 is out of order
# Pages that must come after out of order page 75: {13, 47, 29, 53, 61}
# Swapped 75 with 47: new update is: [97, 75, 47, 61, 53]
# Checking update: [75, 97, 47, 61, 53]
#
# Current page: 75
# Pages that must come after 75: {13, 47, 29, 53, 61}
# Remaining pages: {97, 53, 61, 47}
# Fixed update for now: None
#
# Current page: 97
# Pages that must come after 97: {75, 13, 47, 61, 53, 29}
# Remaining pages: {53, 61, 47}
# Page 75 is out of order
# Pages that must come after out of order page 75: {13, 47, 29, 53, 61}
# Swapped 75 with 47: new update is: [97, 75, 47, 61, 53]
# [61, 13, 29]
# Checking update: [61, 13, 29]
#
# Current page: 61
# Pages that must come after 61: {29, 53, 13}
# Remaining pages: {29, 13}
# Fixed update for now: None
#
# Current page: 13
# Current page 13 is not in rules
#
# Fixed update for now: [61, 29, 13]
#
# Current page: 29
# Pages that must come after 29: {13}
# Remaining pages: set()
# Fixed update for now: [61, 29, 13]
#
# Checking update: [61, 13, 29]
#
# Current page: 61
# Pages that must come after 61: {29, 53, 13}
# Remaining pages: {29, 13}
# Fixed update for now: None
#
# Current page: 13
# Current page 13 is not in rules
#
# Fixed update for now: [61, 29, 13]
#
# Current page: 29
# Pages that must come after 29: {13}
# Remaining pages: set()
# Fixed update for now: [61, 29, 13]
#
# [97, 13, 75, 29, 47]
# Checking update: [97, 13, 75, 29, 47]
#
# Current page: 97
# Pages that must come after 97: {75, 13, 47, 61, 53, 29}
# Remaining pages: {29, 75, 13, 47}
# Fixed update for now: None
#
# Current page: 13
# Current page 13 is not in rules
#
# Fixed update for now: [97, 47, 75, 29, 13]
#
# Current page: 75
# Pages that must come after 75: {13, 47, 29, 53, 61}
# Remaining pages: {13, 29}
# Page 47 is out of order
# Pages that must come after out of order page 47: {29, 13, 61, 53}
# Swapped 47 with 29: new update is: [97, 75, 47, 29, 13]
# Checking update: [97, 13, 75, 29, 47]
#
# Current page: 97
# Pages that must come after 97: {75, 13, 47, 61, 53, 29}
# Remaining pages: {29, 75, 13, 47}
# Fixed update for now: None
#
# Current page: 13
# Current page 13 is not in rules
#
# Fixed update for now: [97, 47, 75, 29, 13]
#
# Current page: 75
# Pages that must come after 75: {13, 47, 29, 53, 61}
# Remaining pages: {13, 29}
# Page 47 is out of order
# Pages that must come after out of order page 47: {29, 13, 61, 53}
# Swapped 47 with 29: new update is: [97, 75, 47, 29, 13]
# 123

# %% [markdown]
# #### Executing the puzzle

# %%
with open("input.txt") as f:
    page_ordering = f.read()

page_ordering = page_ordering.split("\n\n")

rules = page_ordering[0].split()

updates = page_ordering[1].split()
updates = [page.split(",") for page in updates]
updates = [[int(num) for num in update] for update in updates]

x_col, y_col, order, x_ordered = check_order(rules)

# %%
ooo = []
for line in updates:
    is_ordered = check_update_order(line, order)
    if not is_ordered:
        ooo.append(line)

# %%
fixed_updates = []
for line in ooo:
    print(line)
    update_check = fix_update_order(line, order)
    if update_check:
        fixed_updates.append(update_check)
# Out:
# [15, 47, 78, 68, 53]
# Checking update: [15, 47, 78, 68, 53]
#
# Current page: 15
# Pages that must come after 15: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {68, 53, 78, 47}
# Fixed update for now: None
#
# Current page: 47
# Pages that must come after 47: {11, 12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 53, 54, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {68, 53, 78}
# Page 15 is out of order
# Pages that must come after out of order page 15: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Swapped 15 with 53: new update is: [47, 15, 78, 68, 53]
# [11, 36, 88, 13, 59, 38, 46, 34, 71, 68, 12, 31, 92, 54, 47, 44, 29, 37, 64, 78, 74]
# Checking update: [11, 36, 88, 13, 59, 38, 46, 34, 71, 68, 12, 31, 92, 54, 47, 44, 29, 37, 64, 78, 74]
#
# Current page: 11
# Pages that must come after 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {12, 13, 29, 31, 34, 36, 37, 38, 44, 46, 47, 54, 59, 64, 68, 71, 74, 78, 88, 92}
# Fixed update for now: None
#
# Current page: 36
# Pages that must come after 36: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 46, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {12, 13, 29, 31, 34, 37, 38, 44, 46, 47, 54, 59, 64, 68, 71, 74, 78, 88, 92}
# Page 11 is out of order
# Pages that must come after out of order page 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Swapped 11 with 12: new update is: [36, 11, 88, 13, 59, 38, 46, 34, 71, 68, 12, 31, 92, 54, 47, 44, 29, 37, 64, 78, 74]
# [26, 72, 42, 84, 87, 65, 24, 12, 79]
# Checking update: [26, 72, 42, 84, 87, 65, 24, 12, 79]
#
# Current page: 26
# Pages that must come after 26: {17, 18, 23, 24, 25, 35, 42, 47, 49, 51, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {65, 72, 42, 12, 79, 84, 87, 24}
# Fixed update for now: None
#
# Current page: 72
# Pages that must come after 72: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {65, 42, 12, 79, 84, 87, 24}
# Page 26 is out of order
# Pages that must come after out of order page 26: {17, 18, 23, 24, 25, 35, 42, 47, 49, 51, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Swapped 26 with 24: new update is: [72, 26, 42, 84, 87, 65, 24, 12, 79]
# [26, 78, 74, 51, 56, 37, 41, 88, 59, 31, 68, 13, 34, 92, 44, 64, 71, 15, 72]
# Checking update: [26, 78, 74, 51, 56, 37, 41, 88, 59, 31, 68, 13, 34, 92, 44, 64, 71, 15, 72]
#
# Current page: 26
# Pages that must come after 26: {17, 18, 23, 24, 25, 35, 42, 47, 49, 51, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {64, 34, 68, 37, 71, 72, 41, 74, 59, 44, 13, 78, 15, 51, 56, 88, 92, 31}
# Fixed update for now: None
#
# Current page: 78
# Pages that must come after 78: {12, 17, 18, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {64, 34, 68, 37, 71, 72, 41, 74, 59, 44, 13, 15, 51, 56, 88, 92, 31}
# Page 26 is out of order
# Pages that must come after out of order page 26: {17, 18, 23, 24, 25, 35, 42, 47, 49, 51, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Swapped 26 with 51: new update is: [78, 26, 74, 51, 56, 37, 41, 88, 59, 31, 68, 13, 34, 92, 44, 64, 71, 15, 72]
# [72, 82, 89, 83, 92, 37, 42, 53, 87, 73, 76, 26, 78, 49, 79]
# Checking update: [72, 82, 89, 83, 92, 37, 42, 53, 87, 73, 76, 26, 78, 49, 79]
#
# Current page: 72
# Pages that must come after 72: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {37, 73, 42, 76, 78, 79, 49, 82, 83, 53, 87, 89, 26, 92}
# Fixed update for now: None
#
# Current page: 82
# Pages that must come after 82: {17, 18, 23, 24, 25, 34, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 84, 87, 93, 96, 98}
# Remaining pages: {37, 73, 42, 76, 78, 79, 49, 83, 53, 87, 89, 26, 92}
# Fixed update for now: None
#
# Current page: 89
# Pages that must come after 89: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 82, 84, 87, 93, 96, 98}
# Remaining pages: {37, 73, 42, 76, 78, 79, 49, 83, 53, 87, 26, 92}
# Page 82 is out of order
# Pages that must come after out of order page 82: {17, 18, 23, 24, 25, 34, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 84, 87, 93, 96, 98}
# Swapped 82 with 42: new update is: [72, 89, 82, 83, 92, 37, 42, 53, 87, 73, 76, 26, 78, 49, 79]
# [13, 51, 83, 29, 37, 92, 78, 68, 41, 44, 88, 38, 26, 53, 11, 64, 34, 12, 74]
# Checking update: [13, 51, 83, 29, 37, 92, 78, 68, 41, 44, 88, 38, 26, 53, 11, 64, 34, 12, 74]
#
# Current page: 13
# Pages that must come after 13: {12, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Remaining pages: {64, 34, 68, 37, 38, 41, 74, 11, 44, 12, 78, 83, 51, 53, 88, 26, 92, 29}
# Fixed update for now: None
#
# Current page: 51
# Pages that must come after 51: {17, 18, 23, 24, 25, 35, 36, 42, 47, 49, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {64, 34, 68, 37, 38, 41, 74, 11, 44, 12, 78, 83, 53, 88, 26, 92, 29}
# Fixed update for now: None
#
# Current page: 83
# Pages that must come after 83: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 63, 65, 73, 76, 79, 82, 84, 87, 89, 93, 96, 98}
# Remaining pages: {64, 34, 68, 37, 38, 41, 74, 11, 44, 12, 78, 53, 88, 26, 92, 29}
# Fixed update for now: None
#
# Current page: 29
# Pages that must come after 29: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 53, 56, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {64, 34, 68, 37, 38, 41, 74, 11, 44, 12, 78, 53, 88, 26, 92}
# Page 51 is out of order
# Pages that must come after out of order page 51: {17, 18, 23, 24, 25, 35, 36, 42, 47, 49, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Swapped 51 with 83: new update is: [13, 29, 83, 51, 37, 92, 78, 68, 41, 44, 88, 38, 26, 53, 11, 64, 34, 12, 74]
# [23, 35, 63, 42, 46, 25, 93, 79, 98, 87, 36, 54, 18, 76, 73, 49, 65]
# Checking update: [23, 35, 63, 42, 46, 25, 93, 79, 98, 87, 36, 54, 18, 76, 73, 49, 65]
#
# Current page: 23
# Pages that must come after 23: {11, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92, 96}
# Remaining pages: {65, 98, 35, 36, 73, 42, 76, 46, 79, 49, 18, 54, 87, 25, 93, 63}
# Fixed update for now: None
#
# Current page: 35
# Pages that must come after 35: {15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 87, 88, 96, 98}
# Remaining pages: {65, 98, 36, 73, 42, 76, 46, 79, 49, 18, 54, 87, 25, 93, 63}
# Page 23 is out of order
# Pages that must come after out of order page 23: {11, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92, 96}
# Swapped 23 with 36: new update is: [35, 23, 63, 42, 46, 25, 93, 79, 98, 87, 36, 54, 18, 76, 73, 49, 65]
# [51, 64, 72, 37, 12, 42, 35, 49, 89, 82, 73, 26, 93, 56, 13, 29, 79, 78, 92, 24, 83]
# Checking update: [51, 64, 72, 37, 12, 42, 35, 49, 89, 82, 73, 26, 93, 56, 13, 29, 79, 78, 92, 24, 83]
#
# Current page: 51
# Pages that must come after 51: {17, 18, 23, 24, 25, 35, 36, 42, 47, 49, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {12, 13, 24, 26, 29, 35, 37, 42, 49, 56, 64, 72, 73, 78, 79, 82, 83, 89, 92, 93}
# Fixed update for now: None
#
# Current page: 64
# Pages that must come after 64: {12, 17, 24, 25, 26, 29, 35, 37, 42, 49, 51, 53, 56, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Remaining pages: {12, 13, 24, 26, 29, 35, 37, 42, 49, 56, 72, 73, 78, 79, 82, 83, 89, 92, 93}
# Page 51 is out of order
# Pages that must come after out of order page 51: {17, 18, 23, 24, 25, 35, 36, 42, 47, 49, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Swapped 51 with 24: new update is: [64, 51, 72, 37, 12, 42, 35, 49, 89, 82, 73, 26, 93, 56, 13, 29, 79, 78, 92, 24, 83]
# [44, 59, 71, 78, 37, 92, 12, 31, 88]
# Checking update: [44, 59, 71, 78, 37, 92, 12, 31, 88]
#
# Current page: 44
# Pages that must come after 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {37, 71, 12, 78, 88, 59, 92, 31}
# Fixed update for now: None
#
# Current page: 59
# Pages that must come after 59: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 83, 88, 92}
# Remaining pages: {37, 71, 12, 78, 88, 92, 31}
# Page 44 is out of order
# Pages that must come after out of order page 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Swapped 44 with 12: new update is: [59, 44, 71, 78, 37, 92, 12, 31, 88]
# [93, 11, 51, 82, 26, 53, 24, 42, 76]
# Checking update: [93, 11, 51, 82, 26, 53, 24, 42, 76]
#
# Current page: 93
# Pages that must come after 93: {15, 17, 18, 23, 25, 34, 35, 36, 38, 42, 44, 46, 47, 49, 54, 59, 63, 65, 73, 74, 84, 87, 96, 98}
# Remaining pages: {42, 11, 76, 82, 51, 53, 24, 26}
# Fixed update for now: None
#
# Current page: 11
# Pages that must come after 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {42, 76, 82, 51, 53, 24, 26}
# Page 93 is out of order
# Pages that must come after out of order page 93: {15, 17, 18, 23, 25, 34, 35, 36, 38, 42, 44, 46, 47, 49, 54, 59, 63, 65, 73, 74, 84, 87, 96, 98}
# Swapped 93 with 42: new update is: [11, 93, 51, 82, 26, 53, 24, 42, 76]
# [15, 46, 38, 36, 17, 23, 63, 84, 35, 73, 59, 74, 98, 65, 34, 96, 25]
# Checking update: [15, 46, 38, 36, 17, 23, 63, 84, 35, 73, 59, 74, 98, 65, 34, 96, 25]
#
# Current page: 15
# Pages that must come after 15: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {96, 65, 98, 35, 36, 34, 38, 73, 74, 46, 17, 84, 23, 25, 59, 63}
# Fixed update for now: None
#
# Current page: 46
# Pages that must come after 46: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 51, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {96, 65, 98, 35, 36, 34, 38, 73, 74, 17, 84, 23, 25, 59, 63}
# Page 15 is out of order
# Pages that must come after out of order page 15: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Fixed update for now: None
#
# Current page: 38
# Pages that must come after 38: {11, 12, 13, 15, 26, 29, 31, 37, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 82, 83, 88, 89, 92}
# Remaining pages: {96, 65, 98, 35, 36, 34, 73, 74, 17, 84, 23, 25, 59, 63}
# Page 15 is out of order
# Pages that must come after out of order page 15: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Fixed update for now: None
#
# Current page: 36
# Pages that must come after 36: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 46, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {96, 65, 98, 35, 34, 73, 74, 17, 84, 23, 25, 59, 63}
# Page 15 is out of order
# Pages that must come after out of order page 15: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Page 38 is out of order
# Pages that must come after out of order page 38: {11, 12, 13, 15, 26, 29, 31, 37, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 82, 83, 88, 89, 92}
# Swapped 38 with 15: new update is: [15, 46, 36, 38, 17, 23, 63, 84, 35, 73, 59, 74, 98, 65, 34, 96, 25]
# [31, 92, 74, 46, 38, 13, 47, 59, 29, 41, 68, 11, 15, 12, 78, 71, 54, 53, 44]
# Checking update: [31, 92, 74, 46, 38, 13, 47, 59, 29, 41, 68, 11, 15, 12, 78, 71, 54, 53, 44]
#
# Current page: 31
# Pages that must come after 31: {11, 12, 13, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 88, 89, 92, 93}
# Remaining pages: {68, 38, 71, 41, 74, 11, 12, 13, 46, 47, 15, 78, 44, 53, 54, 59, 92, 29}
# Fixed update for now: None
#
# Current page: 92
# Pages that must come after 92: {12, 17, 18, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 72, 73, 76, 79, 82, 83, 84, 87, 89, 93, 98}
# Remaining pages: {68, 38, 71, 41, 74, 11, 12, 13, 46, 47, 15, 78, 44, 53, 54, 59, 29}
# Fixed update for now: None
#
# Current page: 74
# Pages that must come after 74: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {68, 38, 71, 41, 11, 12, 13, 46, 47, 15, 78, 44, 53, 54, 59, 29}
# Page 31 is out of order
# Pages that must come after out of order page 31: {11, 12, 13, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 88, 89, 92, 93}
# Swapped 31 with 11: new update is: [74, 92, 31, 46, 38, 13, 47, 59, 29, 41, 68, 11, 15, 12, 78, 71, 54, 53, 44]
# [87, 42, 18, 98, 72]
# Checking update: [87, 42, 18, 98, 72]
#
# Current page: 87
# Pages that must come after 87: {11, 15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Remaining pages: {72, 42, 18, 98}
# Fixed update for now: None
#
# Current page: 42
# Pages that must come after 42: {15, 18, 23, 25, 31, 34, 35, 36, 38, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 87, 88, 96, 98}
# Remaining pages: {72, 18, 98}
# Page 87 is out of order
# Pages that must come after out of order page 87: {11, 15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Swapped 87 with 18: new update is: [42, 87, 18, 98, 72]
# [13, 89, 11, 64, 73, 76, 29, 26, 53, 72, 56, 17, 83, 42, 37, 49, 78, 82, 79]
# Checking update: [13, 89, 11, 64, 73, 76, 29, 26, 53, 72, 56, 17, 83, 42, 37, 49, 78, 82, 79]
#
# Current page: 13
# Pages that must come after 13: {12, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Remaining pages: {64, 37, 72, 73, 42, 11, 76, 78, 79, 17, 49, 83, 82, 53, 56, 89, 26, 29}
# Fixed update for now: None
#
# Current page: 89
# Pages that must come after 89: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 82, 84, 87, 93, 96, 98}
# Remaining pages: {64, 37, 72, 73, 42, 11, 76, 78, 79, 17, 49, 83, 82, 53, 56, 26, 29}
# Fixed update for now: None
#
# Current page: 11
# Pages that must come after 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {64, 37, 72, 73, 42, 76, 78, 79, 17, 49, 83, 82, 53, 56, 26, 29}
# Page 13 is out of order
# Pages that must come after out of order page 13: {12, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Swapped 13 with 17: new update is: [11, 89, 13, 64, 73, 76, 29, 26, 53, 72, 56, 17, 83, 42, 37, 49, 78, 82, 79]
# [93, 44, 35, 98, 87, 63, 46, 84, 47, 25, 59, 42, 54, 17, 73, 34, 24, 49, 96, 65, 18, 23, 38]
# Checking update: [93, 44, 35, 98, 87, 63, 46, 84, 47, 25, 59, 42, 54, 17, 73, 34, 24, 49, 96, 65, 18, 23, 38]
#
# Current page: 93
# Pages that must come after 93: {15, 17, 18, 23, 25, 34, 35, 36, 38, 42, 44, 46, 47, 49, 54, 59, 63, 65, 73, 74, 84, 87, 96, 98}
# Remaining pages: {17, 18, 23, 24, 25, 34, 35, 38, 42, 44, 46, 47, 49, 54, 59, 63, 65, 73, 84, 87, 96, 98}
# Fixed update for now: None
#
# Current page: 44
# Pages that must come after 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {17, 18, 23, 24, 25, 34, 35, 38, 42, 46, 47, 49, 54, 59, 63, 65, 73, 84, 87, 96, 98}
# Fixed update for now: None
#
# Current page: 35
# Pages that must come after 35: {15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 87, 88, 96, 98}
# Remaining pages: {17, 18, 23, 24, 25, 34, 38, 42, 46, 47, 49, 54, 59, 63, 65, 73, 84, 87, 96, 98}
# Page 44 is out of order
# Pages that must come after out of order page 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Fixed update for now: None
#
# Current page: 98
# Pages that must come after 98: {11, 13, 15, 18, 23, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 64, 65, 68, 71, 74, 84, 88, 96}
# Remaining pages: {17, 18, 23, 24, 25, 34, 38, 42, 46, 47, 49, 54, 59, 63, 65, 73, 84, 87, 96}
# Page 44 is out of order
# Pages that must come after out of order page 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Fixed update for now: None
#
# Current page: 87
# Pages that must come after 87: {11, 15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Remaining pages: {96, 65, 34, 38, 73, 42, 46, 47, 17, 49, 18, 84, 54, 23, 24, 25, 59, 63}
# Page 44 is out of order
# Pages that must come after out of order page 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Page 98 is out of order
# Pages that must come after out of order page 98: {11, 13, 15, 18, 23, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 64, 65, 68, 71, 74, 84, 88, 96}
# Swapped 98 with 18: new update is: [93, 44, 35, 87, 98, 63, 46, 84, 47, 25, 59, 42, 54, 17, 73, 34, 24, 49, 96, 65, 18, 23, 38]
# [83, 56, 42, 12, 92, 73, 49, 72, 93, 18, 98, 87, 37, 17, 79, 82, 63]
# Checking update: [83, 56, 42, 12, 92, 73, 49, 72, 93, 18, 98, 87, 37, 17, 79, 82, 63]
#
# Current page: 83
# Pages that must come after 83: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 63, 65, 73, 76, 79, 82, 84, 87, 89, 93, 96, 98}
# Remaining pages: {98, 37, 72, 73, 42, 12, 79, 49, 18, 17, 82, 87, 56, 92, 93, 63}
# Fixed update for now: None
#
# Current page: 56
# Pages that must come after 56: {17, 18, 23, 24, 25, 26, 35, 42, 47, 49, 51, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {98, 37, 72, 73, 42, 12, 79, 49, 18, 17, 82, 87, 92, 93, 63}
# Page 83 is out of order
# Pages that must come after out of order page 83: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 63, 65, 73, 76, 79, 82, 84, 87, 89, 93, 96, 98}
# Swapped 83 with 17: new update is: [56, 83, 42, 12, 92, 73, 49, 72, 93, 18, 98, 87, 37, 17, 79, 82, 63]
# [49, 23, 96, 42, 79, 98, 65, 59, 84, 87, 34]
# Checking update: [49, 23, 96, 42, 79, 98, 65, 59, 84, 87, 34]
#
# Current page: 49
# Pages that must come after 49: {15, 18, 23, 25, 31, 34, 35, 36, 38, 42, 44, 46, 47, 54, 59, 63, 65, 68, 74, 84, 87, 88, 96, 98}
# Remaining pages: {96, 65, 98, 34, 42, 79, 84, 87, 23, 59}
# Fixed update for now: None
#
# Current page: 23
# Pages that must come after 23: {11, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92, 96}
# Remaining pages: {96, 65, 98, 34, 42, 79, 84, 87, 59}
# Fixed update for now: None
#
# Current page: 96
# Pages that must come after 96: {11, 12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92}
# Remaining pages: {65, 98, 34, 42, 79, 84, 87, 59}
# Fixed update for now: None
#
# Current page: 42
# Pages that must come after 42: {15, 18, 23, 25, 31, 34, 35, 36, 38, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 87, 88, 96, 98}
# Remaining pages: {65, 98, 34, 79, 84, 87, 59}
# Page 23 is out of order
# Pages that must come after out of order page 23: {11, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92, 96}
# Swapped 23 with 34: new update is: [49, 42, 96, 23, 79, 98, 65, 59, 84, 87, 34]
# [47, 11, 59, 38, 23, 41, 44, 54, 34, 64, 71, 15, 63, 84, 46, 36, 88, 74, 31, 96, 18]
# Checking update: [47, 11, 59, 38, 23, 41, 44, 54, 34, 64, 71, 15, 63, 84, 46, 36, 88, 74, 31, 96, 18]
#
# Current page: 47
# Pages that must come after 47: {11, 12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 53, 54, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {11, 15, 18, 23, 31, 34, 36, 38, 41, 44, 46, 54, 59, 63, 64, 71, 74, 84, 88, 96}
# Fixed update for now: None
#
# Current page: 11
# Pages that must come after 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {15, 18, 23, 31, 34, 36, 38, 41, 44, 46, 54, 59, 63, 64, 71, 74, 84, 88, 96}
# Fixed update for now: None
#
# Current page: 59
# Pages that must come after 59: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 83, 88, 92}
# Remaining pages: {64, 96, 34, 36, 38, 71, 41, 74, 44, 46, 15, 18, 84, 54, 23, 88, 31, 63}
# Page 11 is out of order
# Pages that must come after out of order page 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Swapped 11 with 64: new update is: [47, 59, 11, 38, 23, 41, 44, 54, 34, 64, 71, 15, 63, 84, 46, 36, 88, 74, 31, 96, 18]
# [74, 34, 15, 88, 31, 12, 47, 44, 38, 78, 68, 41, 36, 64, 46, 92, 53, 13, 71, 54, 59, 29, 37]
# Checking update: [74, 34, 15, 88, 31, 12, 47, 44, 38, 78, 68, 41, 36, 64, 46, 92, 53, 13, 71, 54, 59, 29, 37]
#
# Current page: 74
# Pages that must come after 74: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 78, 88, 92}
# Fixed update for now: None
#
# Current page: 34
# Pages that must come after 34: {11, 12, 13, 15, 26, 29, 31, 37, 38, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 83, 88, 89, 92}
# Remaining pages: {12, 13, 15, 29, 31, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 78, 88, 92}
# Page 74 is out of order
# Pages that must come after out of order page 74: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Swapped 74 with 12: new update is: [34, 74, 15, 88, 31, 12, 47, 44, 38, 78, 68, 41, 36, 64, 46, 92, 53, 13, 71, 54, 59, 29, 37]
# [46, 41, 36, 88, 44, 47, 74, 63, 54, 65, 15, 84, 59, 23, 96, 98, 13, 11, 31]
# Checking update: [46, 41, 36, 88, 44, 47, 74, 63, 54, 65, 15, 84, 59, 23, 96, 98, 13, 11, 31]
#
# Current page: 46
# Pages that must come after 46: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 51, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {96, 65, 98, 36, 41, 74, 11, 44, 13, 47, 15, 84, 54, 23, 88, 59, 31, 63}
# Fixed update for now: None
#
# Current page: 41
# Pages that must come after 41: {11, 12, 13, 17, 24, 26, 29, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {96, 65, 98, 36, 74, 11, 44, 13, 47, 15, 84, 54, 23, 88, 59, 31, 63}
# Fixed update for now: None
#
# Current page: 36
# Pages that must come after 36: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 46, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {96, 65, 98, 74, 11, 44, 13, 47, 15, 84, 54, 23, 88, 59, 31, 63}
# Page 41 is out of order
# Pages that must come after out of order page 41: {11, 12, 13, 17, 24, 26, 29, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Swapped 41 with 11: new update is: [46, 36, 41, 88, 44, 47, 74, 63, 54, 65, 15, 84, 59, 23, 96, 98, 13, 11, 31]
# [78, 38, 68, 26, 92, 56, 12, 41, 34, 11, 13, 53, 46]
# Checking update: [78, 38, 68, 26, 92, 56, 12, 41, 34, 11, 13, 53, 46]
#
# Current page: 78
# Pages that must come after 78: {12, 17, 18, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {34, 68, 38, 41, 11, 12, 13, 46, 53, 56, 26, 92}
# Fixed update for now: None
#
# Current page: 38
# Pages that must come after 38: {11, 12, 13, 15, 26, 29, 31, 37, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 82, 83, 88, 89, 92}
# Remaining pages: {34, 68, 41, 11, 12, 13, 46, 53, 56, 26, 92}
# Page 78 is out of order
# Pages that must come after out of order page 78: {12, 17, 18, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 79, 82, 83, 87, 89, 92, 93, 98}
# Swapped 78 with 12: new update is: [38, 78, 68, 26, 92, 56, 12, 41, 34, 11, 13, 53, 46]
# [98, 47, 38, 65, 49, 42, 35, 31, 34, 36, 23, 63, 68]
# Checking update: [98, 47, 38, 65, 49, 42, 35, 31, 34, 36, 23, 63, 68]
#
# Current page: 98
# Pages that must come after 98: {11, 13, 15, 18, 23, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 64, 65, 68, 71, 74, 84, 88, 96}
# Remaining pages: {65, 34, 35, 36, 68, 38, 42, 47, 49, 23, 63, 31}
# Fixed update for now: None
#
# Current page: 47
# Pages that must come after 47: {11, 12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 53, 54, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {65, 34, 35, 36, 68, 38, 42, 49, 23, 63, 31}
# Fixed update for now: None
#
# Current page: 38
# Pages that must come after 38: {11, 12, 13, 15, 26, 29, 31, 37, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 82, 83, 88, 89, 92}
# Remaining pages: {65, 34, 35, 36, 68, 42, 49, 23, 63, 31}
# Fixed update for now: None
#
# Current page: 65
# Pages that must come after 65: {11, 13, 15, 23, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 96}
# Remaining pages: {34, 35, 36, 68, 42, 49, 23, 63, 31}
# Page 38 is out of order
# Pages that must come after out of order page 38: {11, 12, 13, 15, 26, 29, 31, 37, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 82, 83, 88, 89, 92}
# Swapped 38 with 31: new update is: [98, 47, 65, 38, 49, 42, 35, 31, 34, 36, 23, 63, 68]
# [87, 68, 65, 17, 46, 74, 63, 59, 47]
# Checking update: [87, 68, 65, 17, 46, 74, 63, 59, 47]
#
# Current page: 87
# Pages that must come after 87: {11, 15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Remaining pages: {65, 68, 74, 46, 47, 17, 59, 63}
# Fixed update for now: None
#
# Current page: 68
# Pages that must come after 68: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92, 93}
# Remaining pages: {65, 74, 46, 47, 17, 59, 63}
# Fixed update for now: None
#
# Current page: 65
# Pages that must come after 65: {11, 13, 15, 23, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 96}
# Remaining pages: {74, 46, 47, 17, 59, 63}
# Page 68 is out of order
# Pages that must come after out of order page 68: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92, 93}
# Fixed update for now: None
#
# Current page: 17
# Pages that must come after 17: {15, 18, 23, 25, 31, 34, 35, 36, 38, 42, 44, 46, 47, 49, 54, 59, 63, 65, 68, 74, 84, 87, 96, 98}
# Remaining pages: {74, 46, 47, 59, 63}
# Page 65 is out of order
# Pages that must come after out of order page 65: {11, 13, 15, 23, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 96}
# Swapped 65 with 46: new update is: [87, 68, 17, 65, 46, 74, 63, 59, 47]
# [11, 23, 59, 88, 84, 34, 31, 44, 36, 18, 64, 15, 71, 41, 65, 13, 68, 54, 38]
# Checking update: [11, 23, 59, 88, 84, 34, 31, 44, 36, 18, 64, 15, 71, 41, 65, 13, 68, 54, 38]
#
# Current page: 11
# Pages that must come after 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {64, 65, 34, 36, 68, 38, 71, 41, 44, 13, 15, 18, 84, 54, 23, 88, 59, 31}
# Fixed update for now: None
#
# Current page: 23
# Pages that must come after 23: {11, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92, 96}
# Remaining pages: {64, 65, 34, 36, 68, 38, 71, 41, 44, 13, 15, 18, 84, 54, 88, 59, 31}
# Page 11 is out of order
# Pages that must come after out of order page 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Swapped 11 with 13: new update is: [23, 11, 59, 88, 84, 34, 31, 44, 36, 18, 64, 15, 71, 41, 65, 13, 68, 54, 38]
# [56, 71, 34, 59, 44, 11, 78, 38, 36]
# Checking update: [56, 71, 34, 59, 44, 11, 78, 38, 36]
#
# Current page: 56
# Pages that must come after 56: {17, 18, 23, 24, 25, 26, 35, 42, 47, 49, 51, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {34, 36, 38, 71, 11, 44, 78, 59}
# Fixed update for now: None
#
# Current page: 71
# Pages that must come after 71: {11, 12, 13, 17, 24, 26, 29, 37, 41, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {34, 36, 38, 11, 44, 78, 59}
# Page 56 is out of order
# Pages that must come after out of order page 56: {17, 18, 23, 24, 25, 26, 35, 42, 47, 49, 51, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Fixed update for now: None
#
# Current page: 34
# Pages that must come after 34: {11, 12, 13, 15, 26, 29, 31, 37, 38, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 83, 88, 89, 92}
# Remaining pages: {36, 38, 11, 44, 78, 59}
# Page 56 is out of order
# Pages that must come after out of order page 56: {17, 18, 23, 24, 25, 26, 35, 42, 47, 49, 51, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Page 71 is out of order
# Pages that must come after out of order page 71: {11, 12, 13, 17, 24, 26, 29, 37, 41, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Swapped 71 with 11: new update is: [56, 34, 71, 59, 44, 11, 78, 38, 36]
# [88, 31, 89, 53, 56, 13, 71]
# Checking update: [88, 31, 89, 53, 56, 13, 71]
#
# Current page: 88
# Pages that must come after 88: {11, 12, 13, 17, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {71, 13, 53, 56, 89, 31}
# Fixed update for now: None
#
# Current page: 31
# Pages that must come after 31: {11, 12, 13, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 88, 89, 92, 93}
# Remaining pages: {71, 13, 53, 56, 89}
# Page 88 is out of order
# Pages that must come after out of order page 88: {11, 12, 13, 17, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Swapped 88 with 13: new update is: [31, 88, 89, 53, 56, 13, 71]
# [84, 76, 24, 96, 18, 87, 73, 65, 36, 23, 54, 17, 93, 49, 83, 82, 79, 35, 42, 63, 47]
# Checking update: [84, 76, 24, 96, 18, 87, 73, 65, 36, 23, 54, 17, 93, 49, 83, 82, 79, 35, 42, 63, 47]
#
# Current page: 84
# Pages that must come after 84: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 78, 88, 96}
# Remaining pages: {17, 18, 23, 24, 35, 36, 42, 47, 49, 54, 63, 65, 73, 76, 79, 82, 83, 87, 93, 96}
# Fixed update for now: None
#
# Current page: 76
# Pages that must come after 76: {17, 18, 23, 24, 25, 34, 35, 36, 38, 42, 44, 46, 47, 49, 54, 59, 63, 65, 73, 84, 87, 93, 96, 98}
# Remaining pages: {17, 18, 23, 24, 35, 36, 42, 47, 49, 54, 63, 65, 73, 79, 82, 83, 87, 93, 96}
# Page 84 is out of order
# Pages that must come after out of order page 84: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 78, 88, 96}
# Swapped 84 with 23: new update is: [76, 84, 24, 96, 18, 87, 73, 65, 36, 23, 54, 17, 93, 49, 83, 82, 79, 35, 42, 63, 47]
# [53, 54, 71, 29, 47, 46, 34, 23, 31, 96, 13, 78, 68, 59, 36, 88, 11, 37, 38, 15, 74]
# Checking update: [53, 54, 71, 29, 47, 46, 34, 23, 31, 96, 13, 78, 68, 59, 36, 88, 11, 37, 38, 15, 74]
#
# Current page: 53
# Pages that must come after 53: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {11, 13, 15, 23, 29, 31, 34, 36, 37, 38, 46, 47, 54, 59, 68, 71, 74, 78, 88, 96}
# Fixed update for now: None
#
# Current page: 54
# Pages that must come after 54: {11, 12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {11, 13, 15, 23, 29, 31, 34, 36, 37, 38, 46, 47, 59, 68, 71, 74, 78, 88, 96}
# Page 53 is out of order
# Pages that must come after out of order page 53: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Swapped 53 with 37: new update is: [54, 53, 71, 29, 47, 46, 34, 23, 31, 96, 13, 78, 68, 59, 36, 88, 11, 37, 38, 15, 74]
# [18, 49, 36, 84, 17, 59, 96, 79, 87, 93, 47, 34, 42, 73, 54]
# Checking update: [18, 49, 36, 84, 17, 59, 96, 79, 87, 93, 47, 34, 42, 73, 54]
#
# Current page: 18
# Pages that must come after 18: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 84, 88, 96}
# Remaining pages: {96, 34, 36, 73, 42, 79, 47, 49, 17, 84, 54, 87, 59, 93}
# Fixed update for now: None
#
# Current page: 49
# Pages that must come after 49: {15, 18, 23, 25, 31, 34, 35, 36, 38, 42, 44, 46, 47, 54, 59, 63, 65, 68, 74, 84, 87, 88, 96, 98}
# Remaining pages: {96, 34, 36, 73, 42, 79, 47, 17, 84, 54, 87, 59, 93}
# Page 18 is out of order
# Pages that must come after out of order page 18: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 84, 88, 96}
# Swapped 18 with 34: new update is: [49, 18, 36, 84, 17, 59, 96, 79, 87, 93, 47, 34, 42, 73, 54]
# [31, 59, 56, 13, 11]
# Checking update: [31, 59, 56, 13, 11]
#
# Current page: 31
# Pages that must come after 31: {11, 12, 13, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 88, 89, 92, 93}
# Remaining pages: {56, 11, 59, 13}
# Fixed update for now: None
#
# Current page: 59
# Pages that must come after 59: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 83, 88, 92}
# Remaining pages: {56, 11, 13}
# Page 31 is out of order
# Pages that must come after out of order page 31: {11, 12, 13, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 88, 89, 92, 93}
# Swapped 31 with 11: new update is: [59, 31, 56, 13, 11]
# [89, 92, 79, 64, 37, 31, 41, 26, 93]
# Checking update: [89, 92, 79, 64, 37, 31, 41, 26, 93]
#
# Current page: 89
# Pages that must come after 89: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 82, 84, 87, 93, 96, 98}
# Remaining pages: {64, 37, 41, 79, 26, 92, 93, 31}
# Fixed update for now: None
#
# Current page: 92
# Pages that must come after 92: {12, 17, 18, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 72, 73, 76, 79, 82, 83, 84, 87, 89, 93, 98}
# Remaining pages: {64, 37, 41, 79, 26, 93, 31}
# Page 89 is out of order
# Pages that must come after out of order page 89: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 82, 84, 87, 93, 96, 98}
# Swapped 89 with 79: new update is: [92, 89, 79, 64, 37, 31, 41, 26, 93]
# [23, 65, 46, 84, 47, 88, 98, 59, 11, 36, 18, 68, 74, 38, 31, 25, 96]
# Checking update: [23, 65, 46, 84, 47, 88, 98, 59, 11, 36, 18, 68, 74, 38, 31, 25, 96]
#
# Current page: 23
# Pages that must come after 23: {11, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92, 96}
# Remaining pages: {96, 65, 98, 36, 68, 38, 74, 11, 46, 47, 18, 84, 88, 25, 59, 31}
# Fixed update for now: None
#
# Current page: 65
# Pages that must come after 65: {11, 13, 15, 23, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 96}
# Remaining pages: {96, 98, 36, 68, 38, 74, 11, 46, 47, 18, 84, 88, 25, 59, 31}
# Page 23 is out of order
# Pages that must come after out of order page 23: {11, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92, 96}
# Swapped 23 with 11: new update is: [65, 23, 46, 84, 47, 88, 98, 59, 11, 36, 18, 68, 74, 38, 31, 25, 96]
# [18, 64, 41, 23, 15, 74, 84, 59, 46, 13, 47, 71, 36, 88, 44, 38, 63, 31, 68, 54, 34, 11, 65]
# Checking update: [18, 64, 41, 23, 15, 74, 84, 59, 46, 13, 47, 71, 36, 88, 44, 38, 63, 31, 68, 54, 34, 11, 65]
#
# Current page: 18
# Pages that must come after 18: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 84, 88, 96}
# Remaining pages: {11, 13, 15, 23, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 64, 65, 68, 71, 74, 84, 88}
# Fixed update for now: None
#
# Current page: 64
# Pages that must come after 64: {12, 17, 24, 25, 26, 29, 35, 37, 42, 49, 51, 53, 56, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Remaining pages: {11, 13, 15, 23, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88}
# Fixed update for now: None
#
# Current page: 41
# Pages that must come after 41: {11, 12, 13, 17, 24, 26, 29, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {11, 13, 15, 23, 31, 34, 36, 38, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88}
# Page 64 is out of order
# Pages that must come after out of order page 64: {12, 17, 24, 25, 26, 29, 35, 37, 42, 49, 51, 53, 56, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Fixed update for now: None
#
# Current page: 23
# Pages that must come after 23: {11, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92, 96}
# Remaining pages: {11, 13, 15, 31, 34, 36, 38, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88}
# Page 41 is out of order
# Pages that must come after out of order page 41: {11, 12, 13, 17, 24, 26, 29, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Swapped 41 with 11: new update is: [18, 64, 23, 41, 15, 74, 84, 59, 46, 13, 47, 71, 36, 88, 44, 38, 63, 31, 68, 54, 34, 11, 65]
# [74, 15, 44, 64, 31, 41, 38, 26, 92, 71, 88, 29, 78, 59, 68, 34, 11, 46, 56]
# Checking update: [74, 15, 44, 64, 31, 41, 38, 26, 92, 71, 88, 29, 78, 59, 68, 34, 11, 46, 56]
#
# Current page: 74
# Pages that must come after 74: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {64, 34, 56, 68, 38, 71, 41, 11, 44, 78, 15, 46, 88, 26, 59, 92, 29, 31}
# Fixed update for now: None
#
# Current page: 15
# Pages that must come after 15: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {64, 34, 56, 68, 38, 71, 41, 11, 44, 78, 46, 88, 26, 59, 92, 29, 31}
# Fixed update for now: None
#
# Current page: 44
# Pages that must come after 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {64, 34, 56, 68, 38, 71, 41, 11, 78, 46, 88, 26, 59, 92, 29, 31}
# Page 15 is out of order
# Pages that must come after out of order page 15: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Swapped 15 with 11: new update is: [74, 44, 15, 64, 31, 41, 38, 26, 92, 71, 88, 29, 78, 59, 68, 34, 11, 46, 56]
# [47, 24, 36, 65, 98, 59, 96, 84, 46, 25, 34, 54, 35, 73, 23, 38, 93, 18, 17, 87, 42, 76, 63]
# Checking update: [47, 24, 36, 65, 98, 59, 96, 84, 46, 25, 34, 54, 35, 73, 23, 38, 93, 18, 17, 87, 42, 76, 63]
#
# Current page: 47
# Pages that must come after 47: {11, 12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 53, 54, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {17, 18, 23, 24, 25, 34, 35, 36, 38, 42, 46, 54, 59, 63, 65, 73, 76, 84, 87, 93, 96, 98}
# Fixed update for now: None
#
# Current page: 24
# Pages that must come after 24: {17, 18, 23, 25, 34, 35, 36, 38, 42, 44, 46, 47, 49, 54, 59, 63, 65, 73, 74, 84, 87, 93, 96, 98}
# Remaining pages: {17, 18, 23, 25, 34, 35, 36, 38, 42, 46, 54, 59, 63, 65, 73, 76, 84, 87, 93, 96, 98}
# Page 47 is out of order
# Pages that must come after out of order page 47: {11, 12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 53, 54, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Swapped 47 with 34: new update is: [24, 47, 36, 65, 98, 59, 96, 84, 46, 25, 34, 54, 35, 73, 23, 38, 93, 18, 17, 87, 42, 76, 63]
# [18, 74, 65, 42, 84, 88, 31, 35, 63]
# Checking update: [18, 74, 65, 42, 84, 88, 31, 35, 63]
#
# Current page: 18
# Pages that must come after 18: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 84, 88, 96}
# Remaining pages: {65, 35, 74, 42, 84, 88, 63, 31}
# Fixed update for now: None
#
# Current page: 74
# Pages that must come after 74: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {65, 35, 42, 84, 88, 63, 31}
# Fixed update for now: None
#
# Current page: 65
# Pages that must come after 65: {11, 13, 15, 23, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 96}
# Remaining pages: {35, 42, 84, 88, 63, 31}
# Page 74 is out of order
# Pages that must come after out of order page 74: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Swapped 74 with 31: new update is: [18, 65, 74, 42, 84, 88, 31, 35, 63]
# [53, 79, 56, 72, 78, 26, 29, 15, 88, 92, 76, 11, 64]
# Checking update: [53, 79, 56, 72, 78, 26, 29, 15, 88, 92, 76, 11, 64]
#
# Current page: 53
# Pages that must come after 53: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {64, 72, 11, 76, 78, 79, 15, 56, 26, 88, 92, 29}
# Fixed update for now: None
#
# Current page: 79
# Pages that must come after 79: {17, 18, 23, 24, 25, 34, 35, 36, 38, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 84, 87, 93, 96, 98}
# Remaining pages: {64, 72, 11, 76, 78, 15, 56, 26, 88, 92, 29}
# Fixed update for now: None
#
# Current page: 56
# Pages that must come after 56: {17, 18, 23, 24, 25, 26, 35, 42, 47, 49, 51, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {64, 72, 11, 76, 78, 15, 88, 26, 92, 29}
# Page 79 is out of order
# Pages that must come after out of order page 79: {17, 18, 23, 24, 25, 34, 35, 36, 38, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 84, 87, 93, 96, 98}
# Swapped 79 with 76: new update is: [53, 56, 79, 72, 78, 26, 29, 15, 88, 92, 76, 11, 64]
# [63, 12, 49, 84, 56, 17, 18, 87, 65]
# Checking update: [63, 12, 49, 84, 56, 17, 18, 87, 65]
#
# Current page: 63
# Pages that must come after 63: {11, 13, 15, 18, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 64, 65, 68, 71, 74, 84, 88, 96}
# Remaining pages: {65, 12, 49, 17, 18, 84, 87, 56}
# Fixed update for now: None
#
# Current page: 12
# Pages that must come after 12: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 72, 73, 76, 79, 82, 83, 84, 87, 89, 93, 98}
# Remaining pages: {65, 49, 18, 17, 84, 87, 56}
# Page 63 is out of order
# Pages that must come after out of order page 63: {11, 13, 15, 18, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 64, 65, 68, 71, 74, 84, 88, 96}
# Swapped 63 with 18: new update is: [12, 63, 49, 84, 56, 17, 18, 87, 65]
# [23, 54, 11, 47, 63, 64, 15]
# Checking update: [23, 54, 11, 47, 63, 64, 15]
#
# Current page: 23
# Pages that must come after 23: {11, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 92, 96}
# Remaining pages: {64, 11, 47, 15, 54, 63}
# Fixed update for now: None
#
# Current page: 54
# Pages that must come after 54: {11, 12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {64, 11, 15, 47, 63}
# Fixed update for now: None
#
# Current page: 11
# Pages that must come after 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {64, 15, 63, 47}
# Fixed update for now: None
#
# Current page: 47
# Pages that must come after 47: {11, 12, 13, 15, 29, 31, 34, 36, 37, 38, 41, 44, 46, 53, 54, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {64, 15, 63}
# Page 11 is out of order
# Pages that must come after out of order page 11: {12, 13, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Swapped 11 with 64: new update is: [23, 54, 47, 11, 63, 64, 15]
# [34, 35, 63, 36, 96, 38, 25, 54, 74, 49, 59]
# Checking update: [34, 35, 63, 36, 96, 38, 25, 54, 74, 49, 59]
#
# Current page: 34
# Pages that must come after 34: {11, 12, 13, 15, 26, 29, 31, 37, 38, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 83, 88, 89, 92}
# Remaining pages: {96, 35, 36, 38, 74, 49, 54, 25, 59, 63}
# Fixed update for now: None
#
# Current page: 35
# Pages that must come after 35: {15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 87, 88, 96, 98}
# Remaining pages: {96, 36, 38, 74, 49, 54, 25, 59, 63}
# Page 34 is out of order
# Pages that must come after out of order page 34: {11, 12, 13, 15, 26, 29, 31, 37, 38, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 83, 88, 89, 92}
# Swapped 34 with 38: new update is: [35, 34, 63, 36, 96, 38, 25, 54, 74, 49, 59]
# [44, 29, 59, 41, 54, 34, 36, 71, 37, 13, 53, 88, 96, 11, 31, 47, 74, 64, 92]
# Checking update: [44, 29, 59, 41, 54, 34, 36, 71, 37, 13, 53, 88, 96, 11, 31, 47, 74, 64, 92]
#
# Current page: 44
# Pages that must come after 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {96, 64, 34, 36, 37, 71, 41, 74, 11, 13, 47, 53, 54, 88, 59, 92, 29, 31}
# Fixed update for now: None
#
# Current page: 29
# Pages that must come after 29: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 53, 56, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {96, 64, 34, 36, 37, 71, 41, 74, 11, 13, 47, 53, 54, 88, 59, 92, 31}
# Fixed update for now: None
#
# Current page: 59
# Pages that must come after 59: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 83, 88, 92}
# Remaining pages: {96, 64, 34, 36, 37, 71, 41, 74, 11, 13, 47, 53, 54, 88, 92, 31}
# Page 29 is out of order
# Pages that must come after out of order page 29: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 53, 56, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Swapped 29 with 37: new update is: [44, 59, 29, 41, 54, 34, 36, 71, 37, 13, 53, 88, 96, 11, 31, 47, 74, 64, 92]
# [56, 84, 25, 42, 87, 23, 73, 76, 96]
# Checking update: [56, 84, 25, 42, 87, 23, 73, 76, 96]
#
# Current page: 56
# Pages that must come after 56: {17, 18, 23, 24, 25, 26, 35, 42, 47, 49, 51, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {96, 73, 42, 76, 84, 87, 23, 25}
# Fixed update for now: None
#
# Current page: 84
# Pages that must come after 84: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 78, 88, 96}
# Remaining pages: {96, 73, 42, 76, 87, 23, 25}
# Fixed update for now: None
#
# Current page: 25
# Pages that must come after 25: {11, 13, 15, 18, 23, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Remaining pages: {96, 73, 42, 76, 87, 23}
# Page 84 is out of order
# Pages that must come after out of order page 84: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 78, 88, 96}
# Swapped 84 with 23: new update is: [56, 25, 84, 42, 87, 23, 73, 76, 96]
# [74, 72, 12, 53, 11, 34, 29, 64, 59, 46, 15]
# Checking update: [74, 72, 12, 53, 11, 34, 29, 64, 59, 46, 15]
#
# Current page: 74
# Pages that must come after 74: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {64, 34, 72, 11, 12, 46, 15, 53, 59, 29}
# Fixed update for now: None
#
# Current page: 72
# Pages that must come after 72: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {64, 34, 11, 12, 46, 15, 53, 59, 29}
# Fixed update for now: None
#
# Current page: 12
# Pages that must come after 12: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 72, 73, 76, 79, 82, 83, 84, 87, 89, 93, 98}
# Remaining pages: {64, 34, 11, 46, 15, 53, 59, 29}
# Page 72 is out of order
# Pages that must come after out of order page 72: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Fixed update for now: None
#
# Current page: 53
# Pages that must come after 53: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {64, 34, 11, 46, 15, 59, 29}
# Page 12 is out of order
# Pages that must come after out of order page 12: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 72, 73, 76, 79, 82, 83, 84, 87, 89, 93, 98}
# Swapped 12 with 72: new update is: [74, 72, 53, 12, 11, 34, 29, 64, 59, 46, 15]
# [12, 72, 79, 26, 56]
# Checking update: [12, 72, 79, 26, 56]
#
# Current page: 12
# Pages that must come after 12: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 72, 73, 76, 79, 82, 83, 84, 87, 89, 93, 98}
# Remaining pages: {72, 26, 56, 79}
# Fixed update for now: None
#
# Current page: 72
# Pages that must come after 72: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {56, 26, 79}
# Fixed update for now: None
#
# Current page: 79
# Pages that must come after 79: {17, 18, 23, 24, 25, 34, 35, 36, 38, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 84, 87, 93, 96, 98}
# Remaining pages: {56, 26}
# Fixed update for now: None
#
# Current page: 26
# Pages that must come after 26: {17, 18, 23, 24, 25, 35, 42, 47, 49, 51, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {56}
# Page 79 is out of order
# Pages that must come after out of order page 79: {17, 18, 23, 24, 25, 34, 35, 36, 38, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 84, 87, 93, 96, 98}
# Fixed update for now: None
#
# Current page: 56
# Pages that must come after 56: {17, 18, 23, 24, 25, 26, 35, 42, 47, 49, 51, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: set()
# Page 26 is out of order
# Pages that must come after out of order page 26: {17, 18, 23, 24, 25, 35, 42, 47, 49, 51, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Swapped 26 with 79: new update is: [12, 72, 79, 56, 26]
# [12, 76, 31, 24, 37, 26, 92, 68, 82, 56, 83, 71, 89, 29, 11, 78, 41, 79, 51]
# Checking update: [12, 76, 31, 24, 37, 26, 92, 68, 82, 56, 83, 71, 89, 29, 11, 78, 41, 79, 51]
#
# Current page: 12
# Pages that must come after 12: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 72, 73, 76, 79, 82, 83, 84, 87, 89, 93, 98}
# Remaining pages: {56, 68, 37, 71, 41, 11, 76, 78, 79, 82, 83, 51, 24, 89, 26, 92, 29, 31}
# Fixed update for now: None
#
# Current page: 76
# ...
# Fixed update for now: None
#
# Current page: 53
# Pages that must come after 53: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {37, 72, 12, 44, 13, 15, 46, 54, 59}
# Fixed update for now: None
#
# Current page: 44
# Pages that must come after 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {37, 72, 12, 13, 46, 15, 54, 59}
# Page 53 is out of order
# Pages that must come after out of order page 53: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Swapped 53 with 12: new update is: [38, 44, 53, 37, 59, 12, 15, 13, 54, 72, 46]
# [13, 93, 41, 12, 26, 89, 31, 29, 82, 71, 92]
# Checking update: [13, 93, 41, 12, 26, 89, 31, 29, 82, 71, 92]
#
# Current page: 13
# Pages that must come after 13: {12, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Remaining pages: {71, 41, 12, 29, 82, 89, 26, 92, 93, 31}
# Fixed update for now: None
#
# Current page: 93
# Pages that must come after 93: {15, 17, 18, 23, 25, 34, 35, 36, 38, 42, 44, 46, 47, 49, 54, 59, 63, 65, 73, 74, 84, 87, 96, 98}
# Remaining pages: {71, 41, 12, 82, 89, 26, 92, 29, 31}
# Fixed update for now: None
#
# Current page: 41
# Pages that must come after 41: {11, 12, 13, 17, 24, 26, 29, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {71, 12, 82, 89, 26, 92, 29, 31}
# Page 13 is out of order
# Pages that must come after out of order page 13: {12, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Swapped 13 with 12: new update is: [41, 93, 13, 12, 26, 89, 31, 29, 82, 71, 92]
# [25, 36, 65, 63, 98, 84, 35, 49, 93, 54, 47, 17, 24]
# Checking update: [25, 36, 65, 63, 98, 84, 35, 49, 93, 54, 47, 17, 24]
#
# Current page: 25
# Pages that must come after 25: {11, 13, 15, 18, 23, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Remaining pages: {65, 98, 35, 36, 47, 49, 17, 84, 54, 24, 93, 63}
# Fixed update for now: None
#
# Current page: 36
# Pages that must come after 36: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 46, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Remaining pages: {65, 98, 35, 47, 49, 17, 84, 54, 24, 93, 63}
# Fixed update for now: None
#
# Current page: 65
# Pages that must come after 65: {11, 13, 15, 23, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 96}
# Remaining pages: {98, 35, 47, 49, 17, 84, 54, 24, 93, 63}
# Page 36 is out of order
# Pages that must come after out of order page 36: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 46, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Fixed update for now: None
#
# Current page: 63
# Pages that must come after 63: {11, 13, 15, 18, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 64, 65, 68, 71, 74, 84, 88, 96}
# Remaining pages: {98, 35, 47, 49, 17, 84, 54, 24, 93}
# Page 36 is out of order
# Pages that must come after out of order page 36: {11, 12, 13, 15, 26, 29, 31, 34, 37, 38, 41, 44, 46, 53, 56, 59, 64, 68, 71, 72, 74, 78, 88, 92}
# Page 65 is out of order
# Pages that must come after out of order page 65: {11, 13, 15, 23, 29, 31, 34, 36, 37, 38, 41, 44, 46, 47, 53, 54, 59, 64, 68, 71, 74, 78, 88, 96}
# Swapped 65 with 36: new update is: [25, 36, 63, 65, 98, 84, 35, 49, 93, 54, 47, 17, 24]
# [44, 42, 31, 63, 98, 68, 49, 84, 34, 18, 15]
# Checking update: [44, 42, 31, 63, 98, 68, 49, 84, 34, 18, 15]
#
# Current page: 44
# Pages that must come after 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {98, 34, 68, 42, 15, 49, 18, 84, 31, 63}
# Fixed update for now: None
#
# Current page: 42
# Pages that must come after 42: {15, 18, 23, 25, 31, 34, 35, 36, 38, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 87, 88, 96, 98}
# Remaining pages: {98, 34, 68, 15, 49, 18, 84, 31, 63}
# Page 44 is out of order
# Pages that must come after out of order page 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Swapped 44 with 15: new update is: [42, 44, 31, 63, 98, 68, 49, 84, 34, 18, 15]
# [34, 12, 88, 37, 74, 41, 15, 71, 38, 13, 92, 31, 83, 11, 51, 56, 64, 68, 53]
# Checking update: [34, 12, 88, 37, 74, 41, 15, 71, 38, 13, 92, 31, 83, 11, 51, 56, 64, 68, 53]
#
# Current page: 34
# Pages that must come after 34: {11, 12, 13, 15, 26, 29, 31, 37, 38, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 83, 88, 89, 92}
# Remaining pages: {64, 68, 37, 38, 71, 41, 74, 11, 12, 13, 15, 83, 51, 53, 88, 56, 92, 31}
# Fixed update for now: None
#
# Current page: 12
# Pages that must come after 12: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 72, 73, 76, 79, 82, 83, 84, 87, 89, 93, 98}
# Remaining pages: {64, 68, 37, 38, 71, 41, 74, 11, 13, 15, 83, 51, 53, 88, 56, 92, 31}
# Fixed update for now: None
#
# Current page: 88
# Pages that must come after 88: {11, 12, 13, 17, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {64, 68, 37, 38, 71, 41, 74, 11, 13, 15, 83, 51, 53, 56, 92, 31}
# Page 12 is out of order
# Pages that must come after out of order page 12: {17, 18, 23, 24, 25, 26, 35, 42, 49, 51, 56, 63, 65, 72, 73, 76, 79, 82, 83, 84, 87, 89, 93, 98}
# Swapped 12 with 51: new update is: [34, 88, 12, 37, 74, 41, 15, 71, 38, 13, 92, 31, 83, 11, 51, 56, 64, 68, 53]
# [89, 49, 83, 76, 78, 64, 26, 93, 41, 53, 73, 24, 79, 51, 17, 37, 92, 11, 72, 29, 82, 13, 56]
# Checking update: [89, 49, 83, 76, 78, 64, 26, 93, 41, 53, 73, 24, 79, 51, 17, 37, 92, 11, 72, 29, 82, 13, 56]
#
# Current page: 89
# Pages that must come after 89: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 82, 84, 87, 93, 96, 98}
# Remaining pages: {11, 13, 17, 24, 26, 29, 37, 41, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 92, 93}
# Fixed update for now: None
#
# Current page: 49
# Pages that must come after 49: {15, 18, 23, 25, 31, 34, 35, 36, 38, 42, 44, 46, 47, 54, 59, 63, 65, 68, 74, 84, 87, 88, 96, 98}
# Remaining pages: {11, 13, 17, 24, 26, 29, 37, 41, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 92, 93}
# Fixed update for now: None
#
# Current page: 83
# Pages that must come after 83: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 63, 65, 73, 76, 79, 82, 84, 87, 89, 93, 96, 98}
# Remaining pages: {11, 13, 17, 24, 26, 29, 37, 41, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 92, 93}
# Page 49 is out of order
# Pages that must come after out of order page 49: {15, 18, 23, 25, 31, 34, 35, 36, 38, 42, 44, 46, 47, 54, 59, 63, 65, 68, 74, 84, 87, 88, 96, 98}
# Page 89 is out of order
# Pages that must come after out of order page 89: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 82, 84, 87, 93, 96, 98}
# Swapped 89 with 17: new update is: [83, 49, 89, 76, 78, 64, 26, 93, 41, 53, 73, 24, 79, 51, 17, 37, 92, 11, 72, 29, 82, 13, 56]
# [44, 37, 38, 59, 74, 92, 31, 54, 47, 46, 64, 41, 78, 36, 15, 96, 68, 88, 11]
# Checking update: [44, 37, 38, 59, 74, 92, 31, 54, 47, 46, 64, 41, 78, 36, 15, 96, 68, 88, 11]
#
# Current page: 44
# Pages that must come after 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {64, 96, 36, 37, 38, 68, 41, 74, 11, 46, 47, 78, 15, 54, 88, 59, 92, 31}
# Fixed update for now: None
#
# Current page: 37
# Pages that must come after 37: {12, 17, 18, 24, 25, 26, 35, 42, 49, 51, 56, 63, 72, 73, 76, 79, 82, 83, 84, 87, 89, 92, 93, 98}
# Remaining pages: {64, 96, 36, 68, 38, 41, 74, 11, 46, 47, 78, 15, 54, 88, 59, 92, 31}
# Fixed update for now: None
#
# Current page: 38
# Pages that must come after 38: {11, 12, 13, 15, 26, 29, 31, 37, 41, 44, 51, 53, 56, 64, 68, 71, 72, 74, 78, 82, 83, 88, 89, 92}
# Remaining pages: {64, 96, 36, 68, 41, 74, 11, 46, 47, 78, 15, 54, 88, 59, 92, 31}
# Page 37 is out of order
# Pages that must come after out of order page 37: {12, 17, 18, 24, 25, 26, 35, 42, 49, 51, 56, 63, 72, 73, 76, 79, 82, 83, 84, 87, 89, 92, 93, 98}
# Swapped 37 with 92: new update is: [44, 38, 37, 59, 74, 92, 31, 54, 47, 46, 64, 41, 78, 36, 15, 96, 68, 88, 11]
# [88, 25, 54, 18, 34, 41, 11, 71, 59, 65, 47, 38, 68]
# Checking update: [88, 25, 54, 18, 34, 41, 11, 71, 59, 65, 47, 38, 68]
#
# Current page: 88
# Pages that must come after 88: {11, 12, 13, 17, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {65, 34, 68, 38, 71, 41, 11, 47, 18, 54, 25, 59}
# Fixed update for now: None
#
# Current page: 25
# Pages that must come after 25: {11, 13, 15, 18, 23, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Remaining pages: {65, 34, 68, 38, 71, 41, 11, 47, 18, 54, 59}
# Page 88 is out of order
# Pages that must come after out of order page 88: {11, 12, 13, 17, 24, 26, 29, 37, 41, 51, 53, 56, 64, 71, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Swapped 88 with 11: new update is: [25, 88, 54, 18, 34, 41, 11, 71, 59, 65, 47, 38, 68]
# [13, 78, 49, 24, 92, 53, 72, 11, 26, 51, 17, 37, 56, 73, 12, 42, 89]
# Checking update: [13, 78, 49, 24, 92, 53, 72, 11, 26, 51, 17, 37, 56, 73, 12, 42, 89]
#
# Current page: 13
# Pages that must come after 13: {12, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Remaining pages: {56, 37, 72, 73, 42, 11, 12, 78, 49, 17, 51, 53, 24, 89, 26, 92}
# Fixed update for now: None
#
# Current page: 78
# Pages that must come after 78: {12, 17, 18, 24, 25, 26, 35, 37, 42, 49, 51, 56, 63, 72, 73, 76, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {56, 37, 72, 73, 42, 11, 12, 49, 17, 51, 53, 24, 89, 26, 92}
# Fixed update for now: None
#
# Current page: 49
# Pages that must come after 49: {15, 18, 23, 25, 31, 34, 35, 36, 38, 42, 44, 46, 47, 54, 59, 63, 65, 68, 74, 84, 87, 88, 96, 98}
# Remaining pages: {56, 37, 72, 73, 42, 11, 12, 17, 51, 53, 24, 89, 26, 92}
# Fixed update for now: None
#
# Current page: 24
# Pages that must come after 24: {17, 18, 23, 25, 34, 35, 36, 38, 42, 44, 46, 47, 49, 54, 59, 63, 65, 73, 74, 84, 87, 93, 96, 98}
# Remaining pages: {37, 72, 73, 42, 11, 12, 17, 51, 53, 56, 89, 26, 92}
# Page 49 is out of order
# Pages that must come after out of order page 49: {15, 18, 23, 25, 31, 34, 35, 36, 38, 42, 44, 46, 47, 54, 59, 63, 65, 68, 74, 84, 87, 88, 96, 98}
# Swapped 49 with 42: new update is: [13, 78, 24, 49, 92, 53, 72, 11, 26, 51, 17, 37, 56, 73, 12, 42, 89]
# [84, 87, 82, 42, 63, 49, 96, 73, 56]
# Checking update: [84, 87, 82, 42, 63, 49, 96, 73, 56]
#
# Current page: 84
# Pages that must come after 84: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 78, 88, 96}
# Remaining pages: {96, 73, 42, 49, 82, 87, 56, 63}
# Fixed update for now: None
#
# Current page: 87
# Pages that must come after 87: {11, 15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Remaining pages: {96, 73, 42, 49, 82, 56, 63}
# Page 84 is out of order
# Pages that must come after out of order page 84: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 78, 88, 96}
# Swapped 84 with 96: new update is: [87, 84, 82, 42, 63, 49, 96, 73, 56]
# [71, 13, 29, 44, 53, 59, 54, 74, 47, 64, 37, 38, 68, 96, 15, 23, 34]
# Checking update: [71, 13, 29, 44, 53, 59, 54, 74, 47, 64, 37, 38, 68, 96, 15, 23, 34]
#
# Current page: 71
# Pages that must come after 71: {11, 12, 13, 17, 24, 26, 29, 37, 41, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 89, 92, 93}
# Remaining pages: {64, 96, 34, 68, 37, 38, 74, 44, 13, 47, 15, 53, 54, 23, 59, 29}
# Fixed update for now: None
#
# Current page: 13
# Pages that must come after 13: {12, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Remaining pages: {64, 96, 34, 68, 37, 38, 74, 44, 47, 15, 53, 54, 23, 59, 29}
# Fixed update for now: None
#
# Current page: 29
# Pages that must come after 29: {12, 17, 24, 25, 26, 35, 37, 42, 49, 51, 53, 56, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93, 98}
# Remaining pages: {64, 96, 34, 68, 37, 38, 74, 44, 47, 15, 53, 54, 23, 59}
# Fixed update for now: None
#
# Current page: 44
# Pages that must come after 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {64, 96, 34, 68, 37, 38, 74, 47, 15, 53, 54, 23, 59}
# Page 13 is out of order
# Pages that must come after out of order page 13: {12, 17, 24, 26, 29, 35, 37, 42, 49, 51, 53, 56, 64, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Swapped 13 with 29: new update is: [71, 44, 29, 13, 53, 59, 54, 74, 47, 64, 37, 38, 68, 96, 15, 23, 34]
# [87, 44, 18, 54, 31, 71, 74, 84, 47, 65, 15, 23, 98, 35, 59]
# Checking update: [87, 44, 18, 54, 31, 71, 74, 84, 47, 65, 15, 23, 98, 35, 59]
#
# Current page: 87
# Pages that must come after 87: {11, 15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Remaining pages: {65, 98, 35, 71, 74, 44, 47, 15, 18, 84, 54, 23, 59, 31}
# Fixed update for now: None
#
# Current page: 44
# Pages that must come after 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Remaining pages: {65, 98, 35, 71, 74, 47, 15, 18, 84, 54, 23, 59, 31}
# Fixed update for now: None
#
# Current page: 18
# Pages that must come after 18: {11, 13, 15, 23, 29, 31, 34, 36, 38, 41, 44, 46, 47, 53, 54, 59, 64, 65, 68, 71, 74, 84, 88, 96}
# Remaining pages: {65, 98, 35, 71, 74, 47, 15, 84, 54, 23, 59, 31}
# Page 44 is out of order
# Pages that must come after out of order page 44: {11, 12, 13, 15, 26, 29, 31, 37, 41, 51, 53, 56, 64, 68, 71, 72, 74, 78, 79, 82, 83, 88, 89, 92}
# Swapped 44 with 15: new update is: [87, 18, 44, 54, 31, 71, 74, 84, 47, 65, 15, 23, 98, 35, 59]
# [79, 51, 68, 12, 53, 29, 72, 26, 83, 71, 88, 11, 31, 13, 74, 82, 15, 37, 64, 92, 56]
# Checking update: [79, 51, 68, 12, 53, 29, 72, 26, 83, 71, 88, 11, 31, 13, 74, 82, 15, 37, 64, 92, 56]
#
# Current page: 79
# Pages that must come after 79: {17, 18, 23, 24, 25, 34, 35, 36, 38, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 84, 87, 93, 96, 98}
# Remaining pages: {11, 12, 13, 15, 26, 29, 31, 37, 51, 53, 56, 64, 68, 71, 72, 74, 82, 83, 88, 92}
# Fixed update for now: None
#
# Current page: 51
# Pages that must come after 51: {17, 18, 23, 24, 25, 35, 36, 42, 47, 49, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Remaining pages: {11, 12, 13, 15, 26, 29, 31, 37, 53, 56, 64, 68, 71, 72, 74, 82, 83, 88, 92}
# Page 79 is out of order
# Pages that must come after out of order page 79: {17, 18, 23, 24, 25, 34, 35, 36, 38, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 84, 87, 93, 96, 98}
# Fixed update for now: None
#
# Current page: 68
# Pages that must come after 68: {11, 12, 13, 24, 26, 29, 31, 37, 41, 51, 53, 56, 64, 71, 72, 76, 78, 79, 82, 83, 88, 89, 92, 93}
# Remaining pages: {64, 56, 37, 71, 72, 74, 11, 12, 13, 15, 82, 83, 53, 88, 26, 92, 29, 31}
# Page 51 is out of order
# Pages that must come after out of order page 51: {17, 18, 23, 24, 25, 35, 36, 42, 47, 49, 54, 63, 65, 73, 76, 79, 82, 83, 84, 87, 89, 93, 96, 98}
# Swapped 51 with 79: new update is: [79, 68, 51, 12, 53, 29, 72, 26, 83, 71, 88, 11, 31, 13, 74, 82, 15, 37, 64, 92, 56]
# [89, 87, 64, 26, 79, 56, 83]
# Checking update: [89, 87, 64, 26, 79, 56, 83]
#
# Current page: 89
# Pages that must come after 89: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 82, 84, 87, 93, 96, 98}
# Remaining pages: {64, 79, 83, 87, 56, 26}
# Fixed update for now: None
#
# Current page: 87
# Pages that must come after 87: {11, 15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Remaining pages: {64, 79, 83, 56, 26}
# Fixed update for now: None
#
# Current page: 64
# Pages that must come after 64: {12, 17, 24, 25, 26, 29, 35, 37, 42, 49, 51, 53, 56, 72, 73, 76, 78, 79, 82, 83, 87, 89, 92, 93}
# Remaining pages: {56, 26, 83, 79}
# Page 87 is out of order
# Pages that must come after out of order page 87: {11, 15, 18, 23, 25, 31, 34, 36, 38, 41, 44, 46, 47, 54, 59, 63, 65, 68, 71, 74, 84, 88, 96, 98}
# Page 89 is out of order
# Pages that must come after out of order page 89: {17, 18, 23, 24, 25, 35, 36, 42, 46, 47, 49, 54, 59, 63, 65, 73, 76, 79, 82, 84, 87, 93, 96, 98}
# Swapped 89 with 79: new update is: [64, 87, 89, 26, 79, 56, 83]

# %%
fixed_page_number_sum = 0
for line in fixed_updates:
    middle = find_middle(line)
    print(f"Middle of {line} is {middle}")
    fixed_page_number_sum += middle

fixed_page_number_sum
# Out:
# Middle of [47, 15, 78, 68, 53] is 78
